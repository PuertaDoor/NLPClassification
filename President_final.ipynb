# %%
import numpy as np
import matplotlib.pyplot as plt

import time
import warnings
warnings.filterwarnings("ignore")

import string
import random
import unicodedata

import codecs
import re
import os.path

from sklearn import *
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD # to reduce dimension in order to prevent from overfitting

from collections import defaultdict, OrderedDict

import nltk
from nltk.corpus import *
from nltk.stem import *
# nltk.download('stopwords')
# nltk.download('punkt')

# %% [markdown]
# # Données reconnaissance du locuteur (Chirac/Mitterrand)

# %% [markdown]
# # A) Transformation paramétrique du texte (pre-traitements)
#
# Vous devez tester, par exemple, les cas suivants:
# - transformation en minuscule ou pas
# - suppression de la ponctuation
# - transformation des mots entièrement en majuscule en marqueurs spécifiques
# - suppression des chiffres ou pas
# - conservation d'une partie du texte seulement (seulement la première ligne = titre, seulement la dernière ligne = résumé, ...)
# - stemming
# - ...
#
#
# Vérifier systématiquement sur un exemple ou deux le bon fonctionnement des méthodes sur deux documents (au moins un de chaque classe).

# %%
# Chargement des données:
def load_pres(fname):
    alltxts = []
    alllabs = []
    s=codecs.open(fname, 'r','utf-8') # pour régler le codage
    while True:
        txt = s.readline()
        if(len(txt))<5:
            break
        #
        lab = re.sub(r"<[0-9]*:[0-9]*:(.)>.*","\\1",txt)
        txt = re.sub(r"<[0-9]*:[0-9]*:.>(.*)","\\1",txt)
        if lab.count('M') >0:
            alllabs.append(-1)
        else: 
            alllabs.append(1)
        alltxts.append(txt)
    return alltxts,alllabs

# %%
fname = "corpus.tache1.learn.utf8"
alltxts,alllabs = load_pres(fname)

# %% [markdown]
# # Données classification de sentiments (films)

# %% [markdown]
# Voir autre fichier

# %% [markdown]
# WE DEFINE OUR GENERALIZED PREPROCESSING FUNCTION BELOW :

# %%
def preproc(alltxts,
            sep_titre_resume=False, # more normal way to treat data if we dont separate, and a normal speech or dialog doesn't have any intro or conclusion
            normalization=True, # we strongly recommend to let it true
            lowercase=True,
            remove_punc=True, # punctuation
            remove_numbers=True,
            remove_sw=True, # sw stands for stopwords
            language="english", # most common language
            lemmatization=True, # we didn't integrate stemming in our preprocessing, we think that lemmatization only is more accurate (even though it needs more resources)
            bytepair_enc=True, # finding most common pairs of words is really informative (if we remove stop words)
            bytepairs_size=0, # max_value = 21, min_value = 1
            ngram=(2,3), # most common ngram range
            maxdf=0.95, # found this value in TMEs
            mindf=2, # same
            maxfeatures=1000, # same
            bin_enc=False): # binary BoW works well on feelings classification (as RITAL course said)
    '''
    Returns the train dataset or the test dataset we will use for our learning process
    @param alltxts : raw texts
    other params are to toggle whether we use associated preproc
    '''
    
    if sep_titre_resume:
        # Séparation en titre/résumé
        debut = time.time()
        for i in range(len(alltxts)):
            sp = alltxts[i].split('\n')
            if len(sp)>1:
                alltxts[i] = sp[0] + " " + sp[-2] # derniere ligne d'une phrase de discours = ligne vide car \n.......
            else:
                alltxts[i] = sp[0]
        fin = time.time()
        
        print("Temps de séparation sous la forme titre/résumé :", fin - debut)
        
    if normalization:
        # Suppr accents et encodage en ascii
        debut = time.time()
        for i in range(len(alltxts)):
            alltxts[i] = unicodedata.normalize('NFD', alltxts[i]).encode('ascii', 'ignore').decode("utf-8")
        fin = time.time()
        
        print("Temps de normalisation :", fin - debut)
        
    
    if lowercase:
        # Suppr minuscules :
        debut = time.time()
        for i in range(len(alltxts)):
            alltxts[i] = alltxts[i].lower()
        fin = time.time()
        
        print("Temps de mise en minuscule :", fin - debut)
        
    
    if remove_punc:
        # Suppr ponctuation :
        debut = time.time()
        punc = string.punctuation
        punc += '\n\r\t'
        for i in range(len(alltxts)):
            alltxts[i] = alltxts[i].translate(str.maketrans(punc, ' ' * len(punc)))
        fin = time.time()
        
        print("Temps de suppression de la ponctuation :", fin - debut)
        
    
    if remove_numbers:
        # Suppr nombres
        debut = time.time()
        for i in range(len(alltxts)):
            alltxts[i] = re.sub('[0-9]+', '', alltxts[i]) # remplacer une séquence de chiffres par rien
            alltxts[i] = re.sub('[ ]+', ' ', alltxts[i])
        fin = time.time()
        
        print("Temps de suppression des nombres :", fin - debut)
    
    
    if remove_sw:
        # Suppr stopwords
        debut = time.time()
        if language=="english":
            stopwords_list = stopwords.words('english')
        else:
            stopwords_list = stopwords.words('french')
        mots = []
        for i in range(len(alltxts)):
            token_textes = nltk.word_tokenize(alltxts[i])
            mots.append([])
            for t in token_textes:
                if t not in stopwords_list:
                    mots[i].append(t)

        for i in range(len(mots)):
            alltxts[i] = " ".join(mots[i])
        fin = time.time()
        
        print("Temps de suppression des stop words :", fin - debut)
        
    
    if lemmatization:
        # Lemmatization (we don't do stemming because we think it is less accurate than lemma)
        debut = time.time()
        lemmatizer = WordNetLemmatizer()
        lem_texte = []
        for i in range(len(alltxts)):
            token_textes = nltk.word_tokenize(alltxts[i])
            lem_texte.append([])
            for t in token_textes:
                lem_texte[i].append(lemmatizer.lemmatize(t))

        mots = []
        i = 0
        for t in lem_texte:
            mots.append([])
            for m in t:
                if len(m)>1:
                    mots[i].append(m)
            i += 1

        for i in range(len(mots)):
            alltxts[i] = " ".join(mots[i])
        fin = time.time()
            
        print("Temps de lemmatization :", fin - debut)
    
    
    if bytepair_enc:
        # Replace most frequent word pair (Byte-Pair encoding)
        debut = time.time()
        pair_freqs = defaultdict(int)

        # we compute the frequency of each pair in the corpus
        for text in alltxts:
            words = text.strip().split(" ")
            for i in range(len(words)-1):
                pair_freqs[words[i] + "_" + words[i+1]] += 1

        sorted_pairfreqs = dict(sorted(pair_freqs.items(),key= lambda x:x[1]))

        most_freq_pairs = list(sorted_pairfreqs.keys())

        bytepairs_size = bytepairs_size # hyper-parameter to toggle
        

        alphabet = ['B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'X', 'Y', 'Z'] # tokens to replace most freq pairs
        
        if bytepairs_size > len(alphabet) or bytepairs_size<1:
            bytepairs_size = len(alphabet)
            
        if bytepairs_size > len(most_freq_pairs):
            bytepairs_size = len(most_freq_pairs)
        
        i_alph = 0
        for i in range(len(most_freq_pairs)-1, len(most_freq_pairs)-bytepairs_size-1, -1):
            to_change = most_freq_pairs[i].split("_")
            for j in range(len(alltxts)):
                words = alltxts[j].strip().split(" ")
                k = 0
                while k < len(words)-1 and len(words)>1:
                    if words[k] == to_change[0] and words[k+1] == to_change[1]:
                        words[k] = alphabet[i_alph]
                        words.pop(k+1)
                        k = 0
                    else:
                        k += 1
                
                alltxts[j] = " ".join(words)

            i_alph += 1
            
        fin = time.time()
            
        print("Temps de Byte-pair Encoding sur les paires de mots :", fin - debut)
    
    
    ngram_range = ngram
    
    # Tfidf is more accurate than Count
    if bin_enc:
        vectorizer = TfidfVectorizer(ngram_range=ngram_range, analyzer='word', max_df=maxdf, min_df=mindf, max_features=maxfeatures, binary=True)
    else:
        vectorizer = TfidfVectorizer(ngram_range=ngram_range, analyzer='word', max_df=maxdf, min_df=mindf, max_features=maxfeatures)
    
    
    
    debut = time.time()
    X = vectorizer.fit_transform(alltxts)
    fin = time.time()
    print("Temps de vectorisation :", fin - debut)
    
    '''
    if tsvd:
        # Réduction dimensionnelle, pas mal pour la gestion de l'overfitting
        if tsvd_size == None:
            tsvd_size = X.shape[0]
            
        debut = time.time()
        reducer = TruncatedSVD(n_components=tsvd_size, n_iter=100, random_state=42)
        X = reducer.fit_transform(X)
        fin = time.time()
        
        print("Temps de réduction dimensionnelle :", fin - debut)
    '''
    
    
    scaler = StandardScaler(with_mean=False) # we assume that standard scaling is necessary in preproc
    
    X = scaler.fit_transform(X) # improvement of 0.07 in scoring
        
    
    return X

# %% [markdown]
# # B) Extraction du vocabulaire (BoW)
#
# - **Exploration préliminaire des jeux de données**
#     - Quelle est la taille d'origine du vocabulaire?
#     - Que reste-t-il si on ne garde que les 100 mots les plus fréquents? [word cloud]
#     - Quels sont les 100 mots dont la fréquence documentaire est la plus grande? [word cloud]
#     - Quels sont les 100 mots les plus discriminants au sens de odds ratio? [word cloud]
#     - Quelle est la distribution d'apparition des mots (Zipf)
#     - Quels sont les 100 bigrammes/trigrammes les plus fréquents?

# %%
from wordcloud import WordCloud, STOPWORDS
from collections import Counter, OrderedDict

alltxts_raw, alllabs_raw = load_pres(fname)

for i in range(len(alltxts_raw)):
    alltxts_raw[i] = alltxts_raw[i].lower()
    
punc = string.punctuation
punc += '\n\r\t'
for i in range(len(alltxts_raw)):
    alltxts_raw[i] = alltxts_raw[i].translate(str.maketrans(punc, ' ' * len(punc)))

# %%
# Taille d'origine du vocabulaire

vocab = []
for i in range(len(alltxts_raw)):
    token_texte = nltk.word_tokenize(alltxts_raw[i])
    for mot in token_texte:
        if mot not in vocab:
            vocab.append(mot)
            
print("Taille d'origine du vocabulaire :", len(vocab))
# Out:
# Taille d'origine du vocabulaire : 28562

# %%
# 100 mots les plus fréquents (word cloud)

most_freq = Counter(" ".join(alltxts_raw).split()).most_common(100)

wordsjoined = " ".join([tup[0] for tup in most_freq])

wc = WordCloud(stopwords=stopwords.words('french')).generate(wordsjoined)

plt.figure()
plt.title("100 mots les plus fréquents (stopwords non inclus)")
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 100 mots dont la fréquence documentaire est la plus grande

token_textes = []
for i in range(len(alltxts_raw)):
    token_textes.append(" ".join(list(set(nltk.word_tokenize(alltxts_raw[i]))))) # on supprime les doublons
          
most_freq = Counter(" ".join(token_textes).split()).most_common(100) # ainsi le counter compte max un même mot par document

wordsjoined = " ".join([tup[0] for tup in most_freq])

wc = WordCloud(stopwords=stopwords.words('french')).generate(wordsjoined)

plt.figure()
plt.title("100 mots avec la plus grande fréquence documentaire (stopwords non inclus)")
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 100 mots les plus discriminants au sens de Odds Ratio
from sklearn.linear_model import LogisticRegression

vect = CountVectorizer()

X = vect.fit_transform(alltxts_raw)

lr = linear_model.LogisticRegression(random_state=42)

lr.fit(X,alllabs_raw)

odds_ratios = np.exp(lr.coef_)

words_100_most_important_oddsratio = np.argsort(np.exp(lr.coef_)) # to get the indices of the 100 most discriminant words
words_discri_idces = words_100_most_important_oddsratio[0][-100:]

feat = vect.get_feature_names_out()
print("Mots les plus discriminants dans l'ordre croissant")
print("Word" + "\t" + "Odd ratio")
for i in words_discri_idces:
    print(feat[i], " ", odds_ratios[0][i])
# Out:
# Word	Odd ratio
# iraq   3.4947059000091385
# concerne   3.495887532322741
# malheureux   3.4970133602075655
# soif   3.5431349972243757
# confirmé   3.543828809630329
# administrative   3.5521793760670715
# guatemala   3.5652307629400743
# sensibilité   3.5836985443314138
# offre   3.6275785355883627
# médicaments   3.6353552016505155
# persuadé   3.6413185498945624
# froide   3.6487117606175343
# réforme   3.6559239109071493
# conserver   3.664861659230077
# terrorisme   3.681585019978502
# affection   3.6930003168973506
# fortement   3.698606071824241
# titre   3.7044210031861775
# prononcé   3.7062154273895827
# mercosur   3.706916484758524
# stabilité   3.7081013959381224
# adoptée   3.7327977639531764
# renouvellement   3.7328386044892845
# lacs   3.7580097348165937
# émotion   3.7763476484809795
# bioéthique   3.7935829954682556
# fracture   3.825376591934954
# réformer   3.835550698059534
# accueillir   3.844083230388324
# ferons   3.8478379773652645
# asie   3.851977363885082
# privilégier   3.8817193252632816
# partager   3.905011615645559
# repères   3.9121864061413723
# corrèze   3.939328132545933
# conséquent   3.953705015551237
# respectueux   3.956724522609046
# cancer   3.9579085796103946
# voudrais   3.968401521555943
# vision   4.012889711362425
# finistère   4.026994717135382
# résolument   4.0385591547011845
# efficace   4.052656921889505
# définitivement   4.060204730886413
# sincères   4.0794965369552045
# handicapées   4.0808824630558815
# manifeste   4.098501440738696
# fédération   4.100033028463771
# efficacement   4.116665816631387
# xxie   4.132358583767121
# mobilisation   4.150511313218361
# imposées   4.161857831432019
# formidable   4.162983278630921
# laval   4.171991480759242
# nice   4.1933631970072005
# chacune   4.221194425407797
# présidente   4.2362816858128305
# ambitieux   4.245501796209521
# visage   4.323288206664593
# civilisations   4.362383086931582
# territoires   4.4064926185247915
# réflexions   4.431880807827484
# compatriotes   4.452022578177803
# défis   4.4563586035535785
# terribles   4.469185275894892
# saurait   4.476002967242374
# exportateur   4.686718077244203
# exercice   4.72393233674074
# processus   4.750372130508493
# sida   4.768471947859407
# sûr   4.773276087190709
# intégration   4.9818726570075205
# constituent   5.022431048618968
# internet   5.1384076552010205
# superbe   5.182175782587191
# éthique   5.277933282860854
# propose   5.279296708643387
# excellence   5.308890747842786
# dynamisme   5.330044698781384
# chers   5.433840049918015
# privilège   5.496621777210369
# coeur   5.621111726097116
# encourager   5.722948056643989
# épouse   5.865302400645281
# hélas   5.894729312450831
# souligné   6.045913693987167
# autorités   6.054381970765008
# défi   6.156764728166229
# g8   6.169510449883726
# guyane   6.243661786135428
# insécurité   6.3784904894116385
# attentes   6.734530150020112
# spontanément   6.74682174664064
# g7   7.500448536805112
# partenariat   8.69064919732508
# probablement   9.544689685645707
# impressionné   10.691063308458086
# 000   15.24976666877914
# euro   15.52520936218792
# mondialisation   17.69742036404951

# %%
# Zipf's law
from math import log

most_freq = Counter(" ".join(alltxts_raw).split()) # from most frequent word to less frequent
most_freq = dict(sorted(most_freq.items(), key=lambda item: item[1], reverse=True))

cpt = 1
log_rank = []
log_freq = []
for k in most_freq.keys():
    log_rank.append(log(cpt))
    log_freq.append(log(most_freq[k])) # log of frequency of the word k
    cpt += 1
    
plt.plot(log_rank, log_freq)
plt.title("Zipf's law visualisation for this dataset")
plt.xlabel("log(rank)")
plt.ylabel("log(frequency)")
plt.show()

# %%
# Most frequent bigrams and trigrams
from nltk.util import ngrams

bigrams = []
trigrams = []
for text in alltxts_raw:
    token = nltk.word_tokenize(text)
    bigrams += ngrams(token,2)
    trigrams += ngrams(token,3)

bigrams_tocount = ["_".join(bigrams[i]) for i in range(len(bigrams))]
trigrams_tocount = ["_".join(trigrams[i]) for i in range(len(trigrams))]

most_freq_bigrams = Counter(bigrams_tocount).most_common(100)
most_freq_trigrams = Counter(trigrams_tocount).most_common(100)

print("Bigrams les plus fréquents :\n", most_freq_bigrams)
print("Trigrams les plus fréquents :\n", most_freq_trigrams)
# Out:
# Bigrams les plus fréquents :
#  [('de_la', 11950), ('de_l', 9422), ('c_est', 7543), ('à_l', 4656), ('et_de', 4383), ('à_la', 4123), ('la_france', 4091), ('aujourd_hui', 2581), ('d_une', 2497), ('dans_le', 2297), ('d_un', 2184), ('qu_il', 1983), ('et_la', 1951), ('de_notre', 1932), ('j_ai', 1854), ('l_europe', 1782), ('de_nos', 1753), ('il_faut', 1718), ('tous_les', 1653), ('dans_la', 1625), ('que_nous', 1610), ('et_les', 1607), ('que_l', 1508), ('monsieur_le', 1507), ('y_a', 1504), ('n_est', 1412), ('il_y', 1411), ('que_la', 1393), ('dans_les', 1361), ('et_à', 1357), ('que_vous', 1304), ('et_des', 1254), ('et_l', 1254), ('que_les', 1216), ('et_le', 1193), ('vous_avez', 1190), ('et_d', 1175), ('d_abord', 1165), ('nous_avons', 1160), ('le_président', 1160), ('et_je', 1156), ('pour_la', 1118), ('dans_l', 1114), ('est_pas', 1108), ('l_union', 1089), ('ce_qui', 1065), ('et_qui', 1061), ('ceux_qui', 1041), ('ce_que', 1024), ('que_je', 1024), ('sur_le', 1024), ('il_est', 1013), ('qui_est', 1000), ('de_ce', 969), ('nous_devons', 959), ('du_monde', 955), ('de_votre', 955), ('pour_l', 955), ('de_cette', 951), ('le_monde', 950), ('l_on', 941), ('qu_elle', 940), ('est_un', 909), ('sur_la', 909), ('par_la', 903), ('que_le', 897), ('qui_ont', 879), ('pour_les', 873), ('de_ses', 856), ('je_suis', 842), ('l_avenir', 839), ('les_plus', 832), ('est_une', 832), ('la_paix', 817), ('d_autres', 795), ('notre_pays', 791), ('qu_ils', 789), ('qui_a', 781), ('toutes_les', 780), ('est_le', 777), ('s_est', 767), ('a_été', 766), ('la_vie', 764), ('est_la', 763), ('de_ces', 756), ('l_etat', 752), ('doit_être', 744), ('est_à', 740), ('par_le', 739), ('que_j', 738), ('mais_aussi', 737), ('je_voudrais', 728), ('de_son', 723), ('il_n', 722), ('sur_les', 718), ('de_leur', 710), ('de_tous', 703), ('d_être', 702), ('tout_à', 691), ('la_république', 674)]
# Trigrams les plus fréquents :
#  [('il_y_a', 1157), ('n_est_pas', 1052), ('de_la_france', 954), ('monsieur_le_président', 923), ('et_de_la', 765), ('l_union_européenne', 642), ('de_l_europe', 579), ('que_l_on', 568), ('c_est_à', 551), ('c_est_un', 532), ('et_de_l', 525), ('dans_le_monde', 516), ('c_est_une', 515), ('c_est_la', 493), ('de_l_homme', 484), ('à_l_heure', 480), ('de_l_union', 479), ('de_la_république', 478), ('et_c_est', 472), ('mesdames_et_messieurs', 448), ('ce_n_est', 447), ('que_j_ai', 409), ('il_n_y', 409), ('c_est_le', 404), ('tout_à_l', 395), ('c_est_aussi', 388), ('et_la_france', 385), ('que_la_france', 385), ('de_la_vie', 373), ('de_plus_en', 356), ('plus_en_plus', 355), ('l_un_des', 352), ('à_la_fois', 352), ('que_vous_avez', 351), ('c_est_l', 350), ('de_tous_les', 343), ('est_à_dire', 343), ('de_l_etat', 338), ('nos_deux_pays', 336), ('c_est_pourquoi', 330), ('c_est_vrai', 323), ('il_s_agit', 313), ('n_y_a', 311), ('dans_le_domaine', 309), ('vous_l_avez', 308), ('la_france_et', 307), ('au_service_de', 298), ('dans_le_cadre', 290), ('de_la_paix', 288), ('la_france_est', 287), ('l_ensemble_des', 280), ('de_notre_pays', 277), ('que_nous_avons', 267), ('qu_il_s', 265), ('je_suis_heureux', 265), ('droits_de_l', 259), ('la_france_a', 256), ('l_avenir_de', 249), ('la_mise_en', 247), ('monsieur_le_maire', 245), ('je_souhaite_que', 244), ('et_à_la', 244), ('tout_à_fait', 242), ('tous_ceux_qui', 241), ('d_entre_vous', 239), ('à_tous_les', 239), ('y_a_pas', 239), ('sur_le_plan', 239), ('la_lutte_contre', 238), ('l_une_des', 237), ('de_la_démocratie', 235), ('que_c_est', 230), ('vous_le_savez', 230), ('président_de_la', 229), ('de_l_histoire', 229), ('n_a_pas', 228), ('au_sein_de', 224), ('l_ensemble_de', 223), ('à_ce_que', 223), ('l_occasion_de', 223), ('entre_nos_deux', 215), ('ne_sont_pas', 212), ('c_est_d', 212), ('ce_qui_est', 208), ('de_la_communauté', 206), ('je_sais_que', 205), ('le_respect_de', 205), ('de_l_autre', 201), ('les_moyens_de', 201), ('de_la_nation', 200), ('au_nom_de', 200), ('je_tiens_à', 200), ('en_même_temps', 199), ('est_d_abord', 199), ('de_l_environnement', 198), ('au_delà_de', 196), ('est_aujourd_hui', 195), ('qu_il_faut', 194), ('chacun_d_entre', 194), ('et_à_l', 194)]

# %% [markdown]
# - **Variantes de BoW**
#     - TF-IDF
#     - Réduire la taille du vocabulaire (min_df, max_df, max_features)
#     - BoW binaire
#     - Bi-grams, tri-grams
#     - **Quelles performances attendrent? Quels sont les avantages et les inconvénients des ces variantes?**

# %% [markdown]
# D'après les différents TMEs ainsi que les 2 premiers cours de RITAL, nous pouvons conclure sur ces points sans tester que :
# - TF-IDF est une technique plus performante de vectorisation que le simple Count car plus informatif sur la fréquence documentaire donc la taille de la variété de contextes dans lesquels utiliser les mots, permet donc de mieux se focaliser sur les mots-clés du corpus.
# - Réduire la taille du vocabulaire est essentiel pour limiter l'overfitting. Enlever les mots les plus couramment utilisés (avec max_df) n'entraîne pas de perte d'information, car ce ne sont souvent pas des mots informatifs. Retirer des mots rares (avec min_df) est aussi une bonne idée car leur présence parasite les résultats (ne donne pas d'information sur le parleur). Enfin, limiter la dimension avec max_features est une bonne idée pour l'overfitting, attention toutefois à ne pas trop en enlever sinon ça retirerait la discrimination nécessaire à la différenciation des deux classes à prédire.
# - D'après le cours, le BoW binaire est surtout utile pour la classification de sentiments. Dans le cas de la prédiction de l'orateur du discours, nous avons besoin de la fréquence exacte des mots utilisés, comme la frontière entre deux présidents est plus floue que la frontière entre les sentiments positifs et négatifs.
# - Utiliser les bi-grams et tri-grams permet de densifier les données, ce qui peut paraître mauvais d'un point de vue dimensionnel mais donne des informations précieuses sur la sémantique, ce qui peut contribuer à une hausse de précision si on applique un pre-processing suffisamment efficace pour limiter la dimensionnalité ainsi qu'une régularisation étudiée pour cela.

# %% [markdown]
# # C) Modèles de Machine Learning

# %% [markdown]
# ## 1) Métriques d'évaluation
#
# Il faudra utiliser des métriques d'évaluation pertinentes suivant la tâche et l'équilibrage des données :
# - Accuracy
# - Courbe ROC, AUC, F1-score

# %% [markdown]
# D'après le web, accuracy ne marche vraiment bien que si les deux classes sont parfaitement équilibrées. Autrement, le score F1 permet de savoir si notre algorithme prédit bien les classes positives (y==1), et ROC_AUC détermine si notre algorithme discrimine comme il faut les positifs des négatifs. Donc ces trois métriques donnent de bonnes informations sur les performances de notre algorithme, si réunies.
#
# Toutefois, nous noterons que F1 s'avère particulièrement efficace pour les problèmes bi-classes et est la métrique la plus informative des trois (sur la précision et le "recall" notamment), nous accorderons donc une importance accrue à cette métrique.
#
# Notre métrique est donc 25% accuracy / 50% F1 / 25% ROC_AUC

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, make_scorer

# %%
def custom_score(y_true, y_pred):
    score = np.array([accuracy_score(y_true, y_pred), f1_score(y_true, y_pred), f1_score(y_true, y_pred), roc_auc_score(y_true, y_pred)]).mean()
    return score

my_score = make_scorer(custom_score, greater_is_better=True)

# %% [markdown]
# ## 2) Variantes sur les stratégies d'entraînement
#
# - **Sur-apprentissage**. Les techniques sur lesquelles nous travaillons étant sujettes au sur-apprentissage: trouver le paramètre de régularisation dans la documentation et optimiser ce paramètre au sens de la métrique qui vous semble la plus appropriée (cf question précédente).
#
#  <br>
# - **Equilibrage des données**. Un problème reconnu comme dur dans la communauté est celui de l'équilibrage des classes (*balance* en anglais). Que faire si les données sont à 80, 90 ou 99% dans une des classes?
# Le problème est dur mais fréquent; les solutions sont multiples mais on peut isoler 3 grandes familles de solution.
#
# 1. Ré-équilibrer le jeu de données: supprimer des données dans la classe majoritaire et/ou sur-échantilloner la classe minoritaire.<BR>
#    $\Rightarrow$ A vous de jouer pour cette technique
# 1. Changer la formulation de la fonction de coût pour pénaliser plus les erreurs dans la classe minoritaire:
# soit une fonction $\Delta$ mesurant les écarts entre $f(x_i)$ et $y_i$
# $$C = \sum_i  \alpha_i \Delta(f(x_i),y_i), \qquad \alpha_i = \left\{
# \begin{array}{ll}
# 1 & \text{si } y_i \in \text{classe majoritaire}\\
# B>1 & \text{si } y_i \in \text{classe minoritaire}\\
# \end{array} \right.$$
# <BR>
#    $\Rightarrow$ Les SVM et d'autres approches sklearn possèdent des arguments pour régler $B$ ou $1/B$... Ces arguments sont utiles mais pas toujours suffisant.
# 1. Courbe ROC et modification du biais. Une fois la fonction $\hat y = f(x)$ apprise, il est possible de la *bidouiller* a posteriori: si toutes les prédictions $\hat y$ sont dans une classe, on va introduire $b$ dans $\hat y = f(x) + b$ et le faire varier jusqu'à ce qu'un des points change de classe. On peut ensuite aller de plus en plus loin.
# Le calcul de l'ensemble des scores associés à cette approche mène directement à la courbe ROC.
#
# **Note:** certains classifieurs sont intrinsèquement plus résistante au problème d'équilibrage, c'est par exemple le cas des techniques de gradient boosting que vous verrez l'an prochain.

# %% [markdown]
# Nous avons décidé d'opter pour la première technique en retirant des phrases de manière aléatoire de la classe majoritaire, bien qu'elle présente l'inconvénient majeur de perdre de l'information puisqu'on supprime littéralement des données de nos datasets. Cela permettra de mettre sur un pied d'égalité tous les classifiers car tous (e.g. Naive Bayes) ne permettent pas de pénaliser la fonction de coût. La troisième approche ne nous a pas semblé plus intéressante que la première.
#
# Nous pensons néanmoins que la meilleure manière d'équilibrer un jeu de données serait de sur-échantillonner la classe majoritaire en utilisant une architecture capable de générer des phrases qui auraient pu être dites par l'un ou l'autre président (e.g. Word2vec, BERT...).

# %%
# !pip install imblearn

# %%
from imblearn.under_sampling import RandomUnderSampler

def balance_classes(X,y): # rend un nouveau X et un nouveau y qui contient autant un label que l'autre
    X_b,y_b = RandomUnderSampler(random_state=42).fit_resample(np.array(X.copy()).reshape(-1,1), y)
    return [item for sublist in X_b.tolist() for item in sublist], y_b

# %% [markdown]
# ## 3) Estimer les performances de généralisation d'une méthodes
# **Ce sera l'enjeu principal du projet : vous disposez d'un ensemble de données, et vous évaluerez les performances sur un ensemble de test auquel vous n'avez pas accès. Il faut donc être capable d'estimer les performances de généralisation du modèles à partir des données d'entraînement.**

# %% [markdown]
# Avant de lancer de grandes expériences, il faut se construire une base de travail solide en étudiant les questions suivantes:
#
# - Combien de temps ça prend d'apprendre un classifieur NB/SVM/RegLog sur ces données en fonction de la taille du vocabulaire?
# - La validation croisée est-elle nécessaire? Est ce qu'on obtient les mêmes résultats avec un simple *split*?
# - La validation croisée est-elle stable? A partir de combien de fold (travailler avec différentes graines aléatoires et faire des statistiques basiques)?

# %%
from sklearn.model_selection import cross_validate, cross_val_score, train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.svm import LinearSVC # single svc takes too much time to execute
from sklearn.linear_model import LogisticRegression

def load_pres_test(fname):
    alltxts = []
    alllabs = []
    s=codecs.open(fname, 'r','utf-8') # pour régler le codage
    while True:
        txt = s.readline()
        if(len(txt))<5:
            break
            
        txt = re.sub(r"<[0-9]*:[0-9]*>(.*)","\\1",txt)
        txt = re.sub(r"<[a-z]*>","",txt)
        alltxts.append(txt)
    return alltxts


fname_train = "corpus.tache1.learn.utf8"
fname_test = "corpus.tache1.test.utf8"

x_train, y_train = load_pres(fname_train)
x_test = load_pres_test(fname_test) # y_test vide

x_train, y_train = balance_classes(x_train, y_train)

# %% [markdown]
# Pour tester l'intérêt de la cross-validation ainsi que déterminer le modèle optimal pour notre problème de classification, nous effectuerons le pre-processing suivant sur les données :

# %%
debut = time.time()
bow_train = preproc(x_train, language="french")
bow_test = preproc(x_test, language="french")
fin = time.time()
print("Temps de preprocessing total :", fin - debut)
# Out:
# Temps de normalisation : 0.03609347343444824
# Temps de mise en minuscule : 0.0035212039947509766
# Temps de suppression de la ponctuation : 0.06304621696472168
# Temps de suppression des nombres : 0.2096560001373291
# Temps de suppression des stop words : 2.928112268447876
# Temps de lemmatization : 4.445380687713623
# Temps de Byte-pair Encoding sur les paires de mots : 1.5096783638000488
# Temps de vectorisation : 1.1568365097045898
# Temps de normalisation : 0.07687711715698242
# Temps de mise en minuscule : 0.0070705413818359375
# Temps de suppression de la ponctuation : 0.12672662734985352
# Temps de suppression des nombres : 0.33373093605041504
# Temps de suppression des stop words : 4.637067079544067
# Temps de lemmatization : 4.171736240386963
# Temps de Byte-pair Encoding sur les paires de mots : 2.176841974258423
# Temps de vectorisation : 1.7387466430664062
# Temps de preprocessing total : 23.706704139709473

# %% [markdown]
# Voir les commentaires disposés çà-et-là dans la définition de la fonction de pre-processing pour comprendre pourquoi nous prenons pour hypothèse que c'est le pre-processing optimal.
#
# On notera que l'ensemble d'entraînement a été balancé, ceci pour permettre à la métrique accuracy d'avoir du sens d'être utilisée et donc avoir des informations plus détaillées sur en tout cas le début de notre optimisation.
#
# De manière générale, limiter au maximum la taille du vocabulaire permet de limiter l'overfitting (réduction de dimensionalité). Donc notre pre-processing s'est attaché à respecter cela.

# %% [markdown]
# Définissons tout de suite le modèle optimal, grâce à nos métriques de score.
#
# Nous allons également jouer sur les différents paramètres de chaque modèle, notamment celui touchant à la régularisation, très important pour limiter l'overfitting. Nous utiliserons la métrique F1 pour mesurer cela (meilleure métrique pour les problèmes de classes binaires, et prédire comme il faut les classes positives tout en estimant bien la sensibilité de notre modèle (recall) nous paraît important).
#
# Lançons la compétition entre les modèles, d'abord interne (on joue sur les paramètres d'un seul et même modèle), puis externe (on fait affronter les modèles avec paramètres optimisés entre eux pour définir le "vainqueur").

# %%
test_scores = []
train_scores = []

# %%
def reglog_opti(bow_train, y_train): # ici, nous allons jouer avec les paramètres que nous estimons déterminants pour le résultat à obtenir
    best_mean = -1
    best_score_f1 = -1
    penalties = ['l1', 'l2', 'elasticnet', None]
    duals = [True, False]
    reg_values = np.arange(0.1, 1.06, 0.05) # regularization in ]0 ; +inf[
    fit_intercepts = [True, False]
    weights_class = ['balanced', None]
    solvers = ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
    l1_ratios = np.arange(0, 1.05, 0.05) # only for elasticnet penalties
    
    '''
    GridSearch à la main :
    
    cpt = 0
    for reg in reg_values:
        for s in solvers:
            for d in duals:
                for f_t in fit_intercepts:
                    for w_c in weights_class:
                        for l1_r in l1_ratios:
                            for p in penalties:
                                try:
                                    print(cpt+1)
                                    cpt += 1
                                    lr = LogisticRegression(penalty=p, dual=d, C=reg, fit_intercept=f_t, class_weight=w_c, random_state=42, solver=s, l1_ratio=l1_r)
                                    score_acc = cross_val_score(lr, bow_train, y_train, scoring='accuracy', cv=5).mean() # on fait avec le score de la cross validation car plus rapide que fit predict etc
                                    score_f1 = cross_val_score(lr, bow_train, y_train, scoring='f1', cv=5).mean()
                                    score_roc_auc = cross_val_score(lr, bow_train, y_train, scoring='roc_auc', cv=5).mean()
                                    curr_mean = np.array([score_acc, score_f1, score_roc_auc]).mean()
                                    if curr_mean > best_mean:
                                        best_mean = curr_mean
                                        pen_opt = p
                                        dual_opt = d
                                        fit_opt = f_t
                                        c_weight_opt = w_c
                                        solver_opt = s
                                        l1_ratio_opt = l1_r
                                    if score_f1 > best_score_f1: # on utilise uniquement la métrique F1 pour définir la régularisation optimale
                                        reg_opt = reg
                                except ValueError:
                                    pass
    
    return LogisticRegression(penalty=pen_opt, dual=dual_opt, C=reg_opt, fit_intercept=fit_opt, class_weight=c_weight_opt, random_state=42, solver=solver_opt, l1_ratio=l1_ratio_opt)
    '''
    
    lr = LogisticRegression(random_state=42)
    
    grid = {'penalty': penalties,
           'dual': duals,
           'C': reg_values,
           'fit_intercept': fit_intercepts,
           'class_weight': weights_class,
           'solver': solvers,
           'l1_ratio': l1_ratios}
    
    search_est = GridSearchCV(estimator=lr, param_grid=grid, scoring=my_score, n_jobs=-1, return_train_score=True)
    
    search_est.fit(bow_train, y_train)
    
    best_train_score = search_est.cv_results_['mean_train_score'][np.argmin(np.array(search_est.cv_results_['rank_test_score']))]
                                    
    return search_est.best_estimator_, search_est.best_score_, best_train_score

# %%
reglog_opt, test_score, train_score = reglog_opti(bow_train, y_train)
test_scores.append(test_score)
train_scores.append(train_score)
print(reglog_opt)
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', l1_ratio=0.0, penalty='l1',
#                    random_state=42, solver='liblinear')

# %%
def lsvc_opti(bow_train, y_train): # ici, nous allons jouer avec les paramètres que nous estimons déterminants pour le résultat à obtenir
    best_mean = -1
    best_score_f1 = -1
    penalties = ['l1', 'l2']
    loss_f = ['hinge', 'squared_hinge']
    duals = [True, False]
    reg_values = np.arange(0.1, 1.01, 0.01) # regularization in ]0 ; +inf[
    fit_intercepts = [True, False]
    weights_class = ['balanced', None]
    
    '''
    
    for reg in reg_values:
        for l in loss_f:
            for d in duals:
                for f_t in fit_intercepts:
                    for p in penalties:
                        for w_c in weights_class:
                            try:
                                lsvc = LinearSVC(penalty=p, loss=l, dual=d, C=reg, fit_intercept=f_t, class_weight=w_c, random_state=42)
                                score_acc = cross_val_score(lsvc, bow_train, y_train, scoring='accuracy', cv=5).mean() # on fait avec le score de la cross validation car plus rapide que fit predict etc
                                score_f1 = cross_val_score(lsvc, bow_train, y_train, scoring='f1', cv=5).mean()
                                score_roc_auc = cross_val_score(lsvc, bow_train, y_train, scoring='roc_auc', cv=5).mean()
                                curr_mean = np.array([score_acc, score_f1, score_roc_auc]).mean()
                                if curr_mean > best_mean:
                                    best_mean = curr_mean
                                    pen_opt = p
                                    loss_opt = l
                                    dual_opt = d
                                    fit_opt = f_t
                                    c_weight_opt = w_c
                                if score_f1 > best_score_f1: # on utilise uniquement la métrique F1 pour définir la régularisation optimale
                                    reg_opt = reg
                            except ValueError:
                                pass
    
    return LinearSVC(penalty=pen_opt, loss=loss_opt, dual=dual_opt, C=reg_opt, fit_intercept=fit_opt, class_weight=c_weight_opt, random_state=42)
    
    '''
    
    lsvc = LinearSVC(random_state=42)
    
    grid = {'penalty': penalties,
            'loss': loss_f,
           'dual': duals,
           'C': reg_values,
           'fit_intercept': fit_intercepts,
           'class_weight': weights_class}
    
    search_est = GridSearchCV(estimator=lsvc, param_grid=grid, scoring=my_score, n_jobs=-1, return_train_score=True)
    
    search_est.fit(bow_train, y_train)
    
    best_train_score = search_est.cv_results_['mean_train_score'][np.argmin(np.array(search_est.cv_results_['rank_test_score']))]
                                    
    return search_est.best_estimator_, search_est.best_score_, best_train_score

# %%
lsvc_opt, test_score, train_score = lsvc_opti(bow_train, y_train)
test_scores.append(test_score)
train_scores.append(train_score)
print(lsvc_opt)
# Out:
# LinearSVC(C=0.15999999999999998, class_weight='balanced', random_state=42)

# %%
def mnb_opti(bow_train, y_train):
    best_mean = -1
    alphas = np.arange(1e-4, 1+1e-4, 1e-4)
    fit_priors = [True, False]
    
    '''

    for a in alphas:
        for f_t in fit_priors: # we don't need to optimize more params, since our classes have the same priority (for the class_prior param)
            try:
                mnb = MultinomialNB(alpha=a, fit_prior=f_t)
                score_acc = cross_val_score(mnb, bow_train, y_train, scoring='accuracy', cv=5).mean() # on fait avec le score de la cross validation car plus rapide que fit predict etc
                score_f1 = cross_val_score(mnb, bow_train, y_train, scoring='f1', cv=5).mean()
                score_roc_auc = cross_val_score(mnb, bow_train, y_train, scoring='roc_auc', cv=5).mean()
                curr_mean = np.array([score_acc, score_f1, score_roc_auc]).mean()
                if curr_mean > best_mean:
                    best_mean = curr_mean
                    alpha_opt = a
                    ft_opt = f_t
            except ValueError:
                pass
    
    
    return MultinomialNB(alpha=alpha_opt, fit_prior=ft_opt)
    '''
    
    mnb = MultinomialNB()
    
    grid = {'alpha': alphas,
            'fit_prior': fit_priors}
    
    search_est = GridSearchCV(estimator=mnb, param_grid=grid, scoring=my_score, n_jobs=-1, return_train_score=True)
    
    search_est.fit(bow_train, y_train)
    
    best_train_score = search_est.cv_results_['mean_train_score'][np.argmin(np.array(search_est.cv_results_['rank_test_score']))]
                                    
    return search_est.best_estimator_, search_est.best_score_, best_train_score

# %%
mnb_opt, test_score, train_score = mnb_opti(bow_train, y_train)
test_scores.append(test_score)
train_scores.append(train_score)
print(mnb_opt)
# Out:
# MultinomialNB(alpha=0.4368)

# %%
def cnb_opti(bow_train, y_train):
    best_mean = -1
    alphas = np.arange(1e-4, 1+1e-4, 1e-4)
    fit_priors = [True, False]
    norms = [True, False]
    
    '''

    for a in alphas:
        for f_t in fit_priors:
            for n in norms:
                try:
                    cnb = ComplementNB(alpha=a, fit_prior=f_t, norm=n)
                    score_acc = cross_val_score(cnb, bow_train, y_train, scoring='accuracy', cv=5).mean() # on fait avec le score de la cross validation car plus rapide que fit predict etc
                    score_f1 = cross_val_score(cnb, bow_train, y_train, scoring='f1', cv=5).mean()
                    score_roc_auc = cross_val_score(cnb, bow_train, y_train, scoring='roc_auc', cv=5).mean()
                    curr_mean = np.array([score_acc, score_f1, score_roc_auc]).mean()
                    if curr_mean > best_mean:
                        best_mean = curr_mean
                        alpha_opt = a
                        ft_opt = f_t
                        norm_opt = n
                except ValueError:
                    pass
                    
    return ComplementNB(alpha=alpha_opt, fit_prior=ft_opt, norm=norm_opt)
    '''
    
    mnb = ComplementNB()
    
    grid = {'alpha': alphas,
            'fit_prior': fit_priors,
            'norm': norms}
    
    search_est = GridSearchCV(estimator=cnb, param_grid=grid, scoring=my_score, n_jobs=-1, return_train_score=True)
    
    search_est.fit(bow_train, y_train)
    
    best_train_score = search_est.cv_results_['mean_train_score'][np.argmin(np.array(search_est.cv_results_['rank_test_score']))]
                                    
    return search_est.best_estimator_, search_est.best_score_, best_train_score

# %%
cnb_opt, test_score, train_score = cnb_opti(bow_train, y_train)
test_scores.append(test_score)
train_scores.append(train_score)
print(cnb_opt)
# Out:
# ComplementNB(alpha=0.007500000000000001, norm=True)

# %% [markdown]
# Déterminons, maintenant que nous avons défini pour chaque classifieur sa version optimale, lequel est le meilleur de tous :

# %%
print(test_scores)
print(train_scores)
# Out:
# [0.6556800300251862, 0.654534900584507, 0.5813436132460273, 0.6556800300251862]
# [0.6983984814168182, 0.6953354515183902, 0.6216733285972694, 0.6983984814168182]

# %%
models_opt = [reglog_opt, lsvc_opt, mnb_opt, cnb_opt]
diff_train_test = []
for i in range(len(train_scores)):
    diff_train_test.append(train_scores[i] - test_scores[i]) # théoriquement, les perfs en test sont moins bonnes qu'en training, on stocke ces resultats pour definir l'overfitting de chaque modele

if np.max(np.array(test_scores)).size > 1:
    meilleur_modele = models_opt[np.argmin(np.array(diff_train_test))] # si plusieurs modeles, on renvoie celui qui overfit le moins
else:
    meilleur_modele = models_opt[np.argmax(np.array(test_scores))] # on renvoie le meilleur modèle d'après le score de test

print("Meilleur modèle selon les critères de base :", meilleur_modele)
# Out:
# Meilleur modèle selon les critères de base : LogisticRegression(C=0.1, class_weight='balanced', l1_ratio=0.0, penalty='l1',
#                    random_state=42, solver='liblinear')

# %% [markdown]
# Maintenant que nous avons notre modèle optimal, nous allons vérifier si la cross-validation vaut le coup d'être utilisée ou non :

# %%
# UTILISÉ EN DEBUG

# meilleur_modele = LogisticRegression(C=0.1, class_weight='balanced', l1_ratio=0.0, penalty='l1', random_state=42, solver='liblinear')

# %%
model = meilleur_modele
scores_cv = []
scores_sp = []
for i in range(100): # on teste 100 fois pour s'assurer du resultat et de sa stabilité
    bow_train_valid, bow_valid, y_train_valid, y_valid = train_test_split(bow_train, y_train, test_size=0.2, random_state=42)
    # notre test_size (qui est en réalité la taille de l'ensemble de validation ici) est de 20%, correspondant au 5-Folds pour la cross val
    model.fit(bow_train_valid, y_train_valid)

    y_pred_valid = model.predict(bow_valid)
    
    my_score_split = custom_score(y_valid, y_pred_valid)
    
    model2 = meilleur_modele
    
    my_score_crossval = cross_val_score(model2, bow_train, y_train, scoring=my_score, cv=5).mean()
    
    
    scores_cv.append(my_score_crossval)
    scores_sp.append(my_score_split)

print(np.array(scores_cv).mean())
print(np.array(scores_sp).mean())
if np.array(scores_cv).mean() > np.array(scores_sp).mean():
    print("Cross-validation mieux")
else:
    print("Cross-val ne vaut pas le coup, gardons ce modèle.")
# Out:
# 0.655680030025186
# 0.6613666895040327
# Cross-val ne vaut pas le coup, gardons ce modèle.

# %% [markdown]
# Nous voyons après exécution de la cellule que la séparation train/test permet de meilleurs résultats, mais il serait intéressant d'implémenter la cross-validation pour trouver le bon ratio entre train et test... quelle valeur de K pour le KFolds serait la plus pertinente ? Nous allons le déterminer maintenant :

# %%
model = meilleur_modele

train_scores = []
test_scores = []
diff_train_test = []
def cross_val(est, X, y, metric, nb_k):
    global test_scores, train_scores, diff_train_test
    results = cross_validate(est, X, y, scoring=metric, cv=nb_k, return_train_score=True)
    train_scores.append(results['train_score'].mean())
    test_scores.append(results['test_score'].mean())
    diff_train_test.append(train_scores[-1] - test_scores[-1])
    
    
kf = range(2, 53) # on va faire varier la taille de la proportion train/test de 50/50 à 98/2 (symétriquement 2/98 car cross val)

for kf_i in kf:
    cross_val(model, bow_train, y_train, my_score, kf_i)
        
plt.plot(kf, train_scores, label='train scores')
plt.plot(kf, test_scores, label='test scores')
plt.xlabel('Nombre de K des KFolds')
plt.ylabel('Scores obtenus')
plt.title('Scores obtenus en fonction des KFolds')

plt.legend()
plt.show()

# on recupere le kf maximisant le score de test :
kf_opt = np.argmax(np.array(test_scores))+2

# si plusieurs K trouvés, on prend le K minimisant l'overfit
if kf_opt.size > 1:
    kf_opt = np.argmin(np.array(diff_train_test))+2
    
print("Nombre de K-Folds optimal :", kf_opt)
# Out:
# Nombre de K-Folds optimal : 10

# %% [markdown]
# Avec notre nombre optimal de Folds, nous aurions pu trouver notre modèle optimal de la manière suivante :

# %%
model = meilleur_modele

results = cross_validate(model, bow_train, y_train, scoring=my_score, cv=kf_opt, return_train_score=True, return_estimator=True)

diff_train_test = [] # on va chercher le meilleur des kf_opt modèles selon le minimum d'overfitting possible
for i in range(kf_opt):
    diff_train_test.append(results['test_score'][i] - results['train_score'][i])

model_opt = np.argmax(np.array(results['test_score']))

if model_opt.size > 1:
    model_tofit = results['estimator'][np.argmax(np.array(diff_train_test))] # difference la plus proche de 0 = modèle qui apprend le plus justement (qui overfit le moins)
else:
    model_tofit = results['estimator'][model_opt]

# %% [markdown]
# On notera que nous n'avons pas besoin des deux cellules ci-dessus pour la suite.

# %% [markdown]
# Maintenant que nous avons notre modèle optimisé, nous pouvons définir quel pre-processing est le meilleur pour notre problème :

# %%
ngram=[(1,1),(1,2),(1,3),(2,2),(2,3),(3,3)] # most common ngram range
maxfeatures=range(0, 2000, 200)
bin_enc=[True, False]

'''
GridSearchCV à la main
'''

best_score = -1
for ng in ngram:
    for mxf in maxfeatures:
        for b_enc in bin_enc:
            try:  
                bow_train = preproc(x_train,
                                    language="french",
                                    ngram=ng,
                                    maxfeatures=mxf,
                                    bin_enc=b_enc)
                results = cross_validate(model_tofit, bow_train, y_train, scoring=my_score, cv=kf_opt, return_train_score=True)
                curr_score = results['test_score'].mean()
                if best_score < curr_score:
                    best_score = curr_score
                    best_train_score = results['train_score'].mean()
                    ng_opt = ng
                    mxf_opt = mxf
                    b_enc_opt = b_enc
            except ValueError:
                pass
                                                            

bow_train_opt = preproc(x_train,
                        language="french",
                        ngram=ng_opt,
                        maxfeatures=mxf_opt,
                        bin_enc=b_enc_opt)


bow_test_opt = preproc(x_test,
                       ngram=ng_opt,
                       maxfeatures=mxf_opt,
                       bin_enc=b_enc_opt)
# Out:
# Temps de normalisation : 0.01191258430480957
# Temps de mise en minuscule : 0.004205465316772461
# Temps de suppression de la ponctuation : 0.06450128555297852
# Temps de suppression des nombres : 0.12998104095458984
# Temps de suppression des stop words : 2.407924175262451
# Temps de lemmatization : 2.923572540283203
# Temps de Byte-pair Encoding sur les paires de mots : 1.525993824005127
# Temps de normalisation : 0.011757850646972656
# Temps de mise en minuscule : 0.0034096240997314453
# Temps de suppression de la ponctuation : 0.06352448463439941
# Temps de suppression des nombres : 0.12694811820983887
# Temps de suppression des stop words : 2.3268399238586426
# Temps de lemmatization : 2.9026265144348145
# Temps de Byte-pair Encoding sur les paires de mots : 1.529792308807373
# Temps de normalisation : 0.011719465255737305
# Temps de mise en minuscule : 0.003225564956665039
# Temps de suppression de la ponctuation : 0.06339263916015625
# Temps de suppression des nombres : 0.13512086868286133
# Temps de suppression des stop words : 2.334629774093628
# Temps de lemmatization : 3.13565993309021
# Temps de Byte-pair Encoding sur les paires de mots : 1.572441816329956
# Temps de vectorisation : 0.22527384757995605
# Temps de normalisation : 0.012028694152832031
# Temps de mise en minuscule : 0.0036084651947021484
# Temps de suppression de la ponctuation : 0.06645083427429199
# Temps de suppression des nombres : 0.1319901943206787
# Temps de suppression des stop words : 2.5194945335388184
# Temps de lemmatization : 2.957911729812622
# Temps de Byte-pair Encoding sur les paires de mots : 1.5275442600250244
# Temps de vectorisation : 0.25763630867004395
# Temps de normalisation : 0.013129234313964844
# Temps de mise en minuscule : 0.003692626953125
# Temps de suppression de la ponctuation : 0.07378840446472168
# Temps de suppression des nombres : 0.14533233642578125
# Temps de suppression des stop words : 2.7565722465515137
# Temps de lemmatization : 3.34592342376709
# Temps de Byte-pair Encoding sur les paires de mots : 2.266819477081299
# Temps de vectorisation : 0.23063993453979492
# Temps de normalisation : 0.011824846267700195
# Temps de mise en minuscule : 0.0033681392669677734
# Temps de suppression de la ponctuation : 0.06768298149108887
# Temps de suppression des nombres : 0.13444948196411133
# Temps de suppression des stop words : 2.4365103244781494
# Temps de lemmatization : 3.0879101753234863
# Temps de Byte-pair Encoding sur les paires de mots : 1.4613068103790283
# Temps de vectorisation : 0.250443696975708
# Temps de normalisation : 0.013652324676513672
# Temps de mise en minuscule : 0.00413060188293457
# Temps de suppression de la ponctuation : 0.07767868041992188
# Temps de suppression des nombres : 0.15218567848205566
# Temps de suppression des stop words : 2.4620563983917236
# Temps de lemmatization : 2.8465306758880615
# Temps de Byte-pair Encoding sur les paires de mots : 1.893068552017212
# Temps de vectorisation : 0.419602632522583
# Temps de normalisation : 0.012074708938598633
# Temps de mise en minuscule : 0.00366973876953125
# Temps de suppression de la ponctuation : 0.06679415702819824
# Temps de suppression des nombres : 0.13425040245056152
# Temps de suppression des stop words : 2.933034896850586
# Temps de lemmatization : 2.874011754989624
# Temps de Byte-pair Encoding sur les paires de mots : 1.5079119205474854
# Temps de vectorisation : 0.24715781211853027
# Temps de normalisation : 0.010972261428833008
# Temps de mise en minuscule : 0.0031890869140625
# Temps de suppression de la ponctuation : 0.06010174751281738
# Temps de suppression des nombres : 0.12007403373718262
# Temps de suppression des stop words : 2.3474583625793457
# Temps de lemmatization : 3.6236515045166016
# Temps de Byte-pair Encoding sur les paires de mots : 1.4757184982299805
# Temps de vectorisation : 0.22249150276184082
# Temps de normalisation : 0.011392354965209961
# Temps de mise en minuscule : 0.0034575462341308594
# Temps de suppression de la ponctuation : 0.06287479400634766
# Temps de suppression des nombres : 0.12401890754699707
# Temps de suppression des stop words : 2.44380784034729
# Temps de lemmatization : 2.7835190296173096
# Temps de Byte-pair Encoding sur les paires de mots : 1.4243826866149902
# Temps de vectorisation : 0.24948716163635254
# Temps de normalisation : 0.010689496994018555
# Temps de mise en minuscule : 0.0032134056091308594
# Temps de suppression de la ponctuation : 0.061284780502319336
# Temps de suppression des nombres : 0.11921238899230957
# Temps de suppression des stop words : 2.8585269451141357
# Temps de lemmatization : 2.647876739501953
# Temps de Byte-pair Encoding sur les paires de mots : 1.3965811729431152
# Temps de vectorisation : 0.21892809867858887
# Temps de normalisation : 0.010921716690063477
# Temps de mise en minuscule : 0.003312826156616211
# Temps de suppression de la ponctuation : 0.06176948547363281
# Temps de suppression des nombres : 0.1226339340209961
# Temps de suppression des stop words : 2.2749364376068115
# Temps de lemmatization : 2.6487209796905518
# Temps de Byte-pair Encoding sur les paires de mots : 1.5322189331054688
# Temps de vectorisation : 0.2262272834777832
# Temps de normalisation : 0.010879993438720703
# Temps de mise en minuscule : 0.003272533416748047
# Temps de suppression de la ponctuation : 0.06057119369506836
# Temps de suppression des nombres : 0.11950373649597168
# Temps de suppression des stop words : 2.205610513687134
# Temps de lemmatization : 2.776780605316162
# Temps de Byte-pair Encoding sur les paires de mots : 1.4195711612701416
# Temps de vectorisation : 0.22177386283874512
# Temps de normalisation : 0.010223388671875
# Temps de mise en minuscule : 0.0027463436126708984
# Temps de suppression de la ponctuation : 0.05587315559387207
# Temps de suppression des nombres : 0.1081686019897461
# Temps de suppression des stop words : 2.0552313327789307
# Temps de lemmatization : 2.511909246444702
# Temps de Byte-pair Encoding sur les paires de mots : 1.3010034561157227
# Temps de vectorisation : 0.19989490509033203
# Temps de normalisation : 0.010512590408325195
# Temps de mise en minuscule : 0.003079652786254883
# Temps de suppression de la ponctuation : 0.056795358657836914
# Temps de suppression des nombres : 0.11187911033630371
# Temps de suppression des stop words : 2.172149419784546
# Temps de lemmatization : 2.546067953109741
# Temps de Byte-pair Encoding sur les paires de mots : 1.2882421016693115
# Temps de vectorisation : 0.19916105270385742
# Temps de normalisation : 0.010199785232543945
# Temps de mise en minuscule : 0.003141641616821289
# Temps de suppression de la ponctuation : 0.05634951591491699
# Temps de suppression des nombres : 0.10848069190979004
# Temps de suppression des stop words : 2.2753679752349854
# Temps de lemmatization : 2.5787136554718018
# Temps de Byte-pair Encoding sur les paires de mots : 1.2436256408691406
# Temps de vectorisation : 0.1943068504333496
# Temps de normalisation : 0.010304927825927734
# Temps de mise en minuscule : 0.0029754638671875
# Temps de suppression de la ponctuation : 0.05629396438598633
# Temps de suppression des nombres : 0.10927557945251465
# Temps de suppression des stop words : 2.0156235694885254
# Temps de lemmatization : 2.4197826385498047
# Temps de Byte-pair Encoding sur les paires de mots : 1.2327077388763428
# Temps de vectorisation : 0.1916215419769287
# Temps de normalisation : 0.009933233261108398
# Temps de mise en minuscule : 0.0028312206268310547
# Temps de suppression de la ponctuation : 0.05556774139404297
# Temps de suppression des nombres : 0.10787582397460938
# Temps de suppression des stop words : 1.982403039932251
# Temps de lemmatization : 2.3940722942352295
# Temps de Byte-pair Encoding sur les paires de mots : 1.242978811264038
# Temps de vectorisation : 0.19301772117614746
# Temps de normalisation : 0.010099172592163086
# Temps de mise en minuscule : 0.0031273365020751953
# Temps de suppression de la ponctuation : 0.055242061614990234
# Temps de suppression des nombres : 0.10748720169067383
# Temps de suppression des stop words : 2.068453311920166
# Temps de lemmatization : 2.3821139335632324
# Temps de Byte-pair Encoding sur les paires de mots : 1.2175042629241943
# Temps de vectorisation : 0.19234418869018555
# Temps de normalisation : 0.009745359420776367
# Temps de mise en minuscule : 0.002856016159057617
# Temps de suppression de la ponctuation : 0.05456185340881348
# Temps de suppression des nombres : 0.1047978401184082
# Temps de suppression des stop words : 1.956617832183838
# Temps de lemmatization : 2.33691143989563
# Temps de Byte-pair Encoding sur les paires de mots : 1.2245304584503174
# Temps de vectorisation : 0.18904805183410645
# Temps de normalisation : 0.009773015975952148
# Temps de mise en minuscule : 0.002835988998413086
# Temps de suppression de la ponctuation : 0.0549464225769043
# Temps de suppression des nombres : 0.10539007186889648
# Temps de suppression des stop words : 1.9638760089874268
# Temps de lemmatization : 2.3292622566223145
# Temps de Byte-pair Encoding sur les paires de mots : 1.2201175689697266
# Temps de normalisation : 0.029826879501342773
# Temps de mise en minuscule : 0.009680986404418945
# Temps de suppression de la ponctuation : 0.13757586479187012
# Temps de suppression des nombres : 0.12531113624572754
# Temps de suppression des stop words : 2.0629496574401855
# Temps de lemmatization : 2.3402950763702393
# Temps de Byte-pair Encoding sur les paires de mots : 1.2104103565216064
# Temps de normalisation : 0.008630752563476562
# Temps de mise en minuscule : 0.002775907516479492
# Temps de suppression de la ponctuation : 0.051239967346191406
# Temps de suppression des nombres : 0.10287284851074219
# Temps de suppression des stop words : 1.9877417087554932
# Temps de lemmatization : 2.355102777481079
# Temps de Byte-pair Encoding sur les paires de mots : 1.1800181865692139
# Temps de vectorisation : 0.6304347515106201
# Temps de normalisation : 0.009997844696044922
# Temps de mise en minuscule : 0.0029196739196777344
# Temps de suppression de la ponctuation : 0.05480313301086426
# Temps de suppression des nombres : 0.10304903984069824
# Temps de suppression des stop words : 1.949845314025879
# Temps de lemmatization : 2.3248229026794434
# Temps de Byte-pair Encoding sur les paires de mots : 1.1934866905212402
# Temps de vectorisation : 0.6306531429290771
# Temps de normalisation : 0.009496688842773438
# Temps de mise en minuscule : 0.003080129623413086
# Temps de suppression de la ponctuation : 0.05485701560974121
# Temps de suppression des nombres : 0.10240054130554199
# Temps de suppression des stop words : 1.912870168685913
# Temps de lemmatization : 2.456509828567505
# Temps de Byte-pair Encoding sur les paires de mots : 1.2365367412567139
# Temps de vectorisation : 0.6420176029205322
# Temps de normalisation : 0.00947117805480957
# Temps de mise en minuscule : 0.0027875900268554688
# Temps de suppression de la ponctuation : 0.05307197570800781
# Temps de suppression des nombres : 0.10101842880249023
# Temps de suppression des stop words : 1.9100918769836426
# Temps de lemmatization : 2.320446491241455
# Temps de Byte-pair Encoding sur les paires de mots : 1.1934025287628174
# Temps de vectorisation : 0.6353399753570557
# Temps de normalisation : 0.009747743606567383
# Temps de mise en minuscule : 0.002887248992919922
# Temps de suppression de la ponctuation : 0.05392885208129883
# Temps de suppression des nombres : 0.10432958602905273
# Temps de suppression des stop words : 2.6034810543060303
# Temps de lemmatization : 2.383836507797241
# Temps de Byte-pair Encoding sur les paires de mots : 1.1920287609100342
# Temps de vectorisation : 0.6341233253479004
# Temps de normalisation : 0.009959220886230469
# Temps de mise en minuscule : 0.0028638839721679688
# Temps de suppression de la ponctuation : 0.053626298904418945
# Temps de suppression des nombres : 0.10387992858886719
# Temps de suppression des stop words : 1.9235224723815918
# Temps de lemmatization : 2.4204447269439697
# Temps de Byte-pair Encoding sur les paires de mots : 1.1775505542755127
# Temps de vectorisation : 0.6314563751220703
# Temps de normalisation : 0.009902238845825195
# Temps de mise en minuscule : 0.0028760433197021484
# Temps de suppression de la ponctuation : 0.0534665584564209
# Temps de suppression des nombres : 0.10225152969360352
# Temps de suppression des stop words : 1.912693977355957
# Temps de lemmatization : 2.316025733947754
# Temps de Byte-pair Encoding sur les paires de mots : 1.1709926128387451
# Temps de vectorisation : 0.638444185256958
# Temps de normalisation : 0.009682178497314453
# Temps de mise en minuscule : 0.002834320068359375
# Temps de suppression de la ponctuation : 0.05362963676452637
# Temps de suppression des nombres : 0.10317754745483398
# Temps de suppression des stop words : 1.9540305137634277
# Temps de lemmatization : 2.284116506576538
# Temps de Byte-pair Encoding sur les paires de mots : 1.1859309673309326
# Temps de vectorisation : 0.6310024261474609
# Temps de normalisation : 0.009656667709350586
# Temps de mise en minuscule : 0.0028276443481445312
# Temps de suppression de la ponctuation : 0.05359625816345215
# Temps de suppression des nombres : 0.10628318786621094
# Temps de suppression des stop words : 1.9279348850250244
# Temps de lemmatization : 2.4286370277404785
# Temps de Byte-pair Encoding sur les paires de mots : 1.183342695236206
# Temps de vectorisation : 0.6421120166778564
# Temps de normalisation : 0.009805679321289062
# Temps de mise en minuscule : 0.002760171890258789
# Temps de suppression de la ponctuation : 0.053217172622680664
# Temps de suppression des nombres : 0.10233879089355469
# Temps de suppression des stop words : 1.9360885620117188
# Temps de lemmatization : 2.8852808475494385
# Temps de Byte-pair Encoding sur les paires de mots : 1.2658212184906006
# Temps de vectorisation : 0.6270570755004883
# Temps de normalisation : 0.009720087051391602
# Temps de mise en minuscule : 0.0029554367065429688
# Temps de suppression de la ponctuation : 0.054259300231933594
# Temps de suppression des nombres : 0.10127377510070801
# Temps de suppression des stop words : 1.9235780239105225
# Temps de lemmatization : 2.2971384525299072
# Temps de Byte-pair Encoding sur les paires de mots : 1.1817076206207275
# Temps de vectorisation : 0.6322152614593506
# Temps de normalisation : 0.009515047073364258
# Temps de mise en minuscule : 0.002961397171020508
# Temps de suppression de la ponctuation : 0.052697181701660156
# Temps de suppression des nombres : 0.10045361518859863
# Temps de suppression des stop words : 1.8964524269104004
# Temps de lemmatization : 2.404728889465332
# Temps de Byte-pair Encoding sur les paires de mots : 1.1651043891906738
# Temps de vectorisation : 0.6246156692504883
# Temps de normalisation : 0.00995492935180664
# Temps de mise en minuscule : 0.002783060073852539
# Temps de suppression de la ponctuation : 0.0538175106048584
# Temps de suppression des nombres : 0.1008296012878418
# Temps de suppression des stop words : 1.9192869663238525
# Temps de lemmatization : 2.2715601921081543
# Temps de Byte-pair Encoding sur les paires de mots : 1.1580593585968018
# Temps de vectorisation : 0.6226134300231934
# Temps de normalisation : 0.009730100631713867
# Temps de mise en minuscule : 0.002856016159057617
# Temps de suppression de la ponctuation : 0.0529632568359375
# Temps de suppression des nombres : 0.09933185577392578
# Temps de suppression des stop words : 1.877758502960205
# Temps de lemmatization : 2.294328212738037
# Temps de Byte-pair Encoding sur les paires de mots : 1.174043893814087
# Temps de vectorisation : 0.6240191459655762
# Temps de normalisation : 0.009837865829467773
# Temps de mise en minuscule : 0.002780437469482422
# Temps de suppression de la ponctuation : 0.05215167999267578
# Temps de suppression des nombres : 0.09802651405334473
# Temps de suppression des stop words : 1.886230707168579
# Temps de lemmatization : 2.4584248065948486
# Temps de Byte-pair Encoding sur les paires de mots : 1.1450920104980469
# Temps de vectorisation : 0.6124203205108643
# Temps de normalisation : 0.011822700500488281
# Temps de mise en minuscule : 0.003707408905029297
# Temps de suppression de la ponctuation : 0.06449174880981445
# Temps de suppression des nombres : 0.12188482284545898
# Temps de suppression des stop words : 1.857391357421875
# Temps de lemmatization : 2.228309154510498
# Temps de Byte-pair Encoding sur les paires de mots : 1.1623568534851074
# Temps de vectorisation : 0.6104631423950195
# Temps de normalisation : 0.009672403335571289
# Temps de mise en minuscule : 0.0028083324432373047
# Temps de suppression de la ponctuation : 0.052165985107421875
# Temps de suppression des nombres : 0.09864211082458496
# Temps de suppression des stop words : 1.860614538192749
# Temps de lemmatization : 2.2587199211120605
# Temps de Byte-pair Encoding sur les paires de mots : 1.1384711265563965
# Temps de vectorisation : 0.6061515808105469
# Temps de normalisation : 0.009473085403442383
# Temps de mise en minuscule : 0.0027801990509033203
# Temps de suppression de la ponctuation : 0.051976919174194336
# Temps de suppression des nombres : 0.09825825691223145
# Temps de suppression des stop words : 1.899867057800293
# Temps de lemmatization : 2.463946580886841
# Temps de Byte-pair Encoding sur les paires de mots : 1.1724061965942383
# Temps de vectorisation : 0.6059200763702393
# Temps de normalisation : 0.009537935256958008
# Temps de mise en minuscule : 0.0026416778564453125
# Temps de suppression de la ponctuation : 0.05210137367248535
# Temps de suppression des nombres : 0.09814023971557617
# Temps de suppression des stop words : 1.875993251800537
# Temps de lemmatization : 2.22847318649292
# Temps de Byte-pair Encoding sur les paires de mots : 1.142423391342163
# Temps de normalisation : 0.009395122528076172
# Temps de mise en minuscule : 0.002759218215942383
# Temps de suppression de la ponctuation : 0.0524594783782959
# Temps de suppression des nombres : 0.0980064868927002
# Temps de suppression des stop words : 1.8796517848968506
# Temps de lemmatization : 2.241074323654175
# Temps de Byte-pair Encoding sur les paires de mots : 1.1377811431884766
# Temps de normalisation : 0.009496212005615234
# Temps de mise en minuscule : 0.0028841495513916016
# Temps de suppression de la ponctuation : 0.052573442459106445
# Temps de suppression des nombres : 0.09941887855529785
# Temps de suppression des stop words : 1.895183801651001
# Temps de lemmatization : 2.379382371902466
# Temps de Byte-pair Encoding sur les paires de mots : 1.2295479774475098
# Temps de vectorisation : 1.0655765533447266
# Temps de normalisation : 0.009641647338867188
# Temps de mise en minuscule : 0.0028285980224609375
# Temps de suppression de la ponctuation : 0.05290842056274414
# Temps de suppression des nombres : 0.09859633445739746
# Temps de suppression des stop words : 1.8844389915466309
# Temps de lemmatization : 2.234916925430298
# Temps de Byte-pair Encoding sur les paires de mots : 1.1276540756225586
# Temps de vectorisation : 1.0609960556030273
# Temps de normalisation : 0.009409189224243164
# Temps de mise en minuscule : 0.0029027462005615234
# Temps de suppression de la ponctuation : 0.05086398124694824
# Temps de suppression des nombres : 0.09559226036071777
# Temps de suppression des stop words : 1.8750941753387451
# Temps de lemmatization : 2.5077168941497803
# Temps de Byte-pair Encoding sur les paires de mots : 1.2920920848846436
# Temps de vectorisation : 1.1777894496917725
# Temps de normalisation : 0.011705160140991211
# Temps de mise en minuscule : 0.0031807422637939453
# Temps de suppression de la ponctuation : 0.06767892837524414
# Temps de suppression des nombres : 0.12115931510925293
# Temps de suppression des stop words : 2.1263349056243896
# Temps de lemmatization : 2.515350341796875
# Temps de Byte-pair Encoding sur les paires de mots : 1.274681568145752
# Temps de vectorisation : 1.129990577697754
# Temps de normalisation : 0.01078033447265625
# Temps de mise en minuscule : 0.0031261444091796875
# Temps de suppression de la ponctuation : 0.06029796600341797
# Temps de suppression des nombres : 0.11294937133789062
# Temps de suppression des stop words : 2.1921865940093994
# Temps de lemmatization : 2.3511366844177246
# Temps de Byte-pair Encoding sur les paires de mots : 1.1983580589294434
# Temps de vectorisation : 1.0826938152313232
# Temps de normalisation : 0.009830951690673828
# Temps de mise en minuscule : 0.0028998851776123047
# Temps de suppression de la ponctuation : 0.056696414947509766
# Temps de suppression des nombres : 0.10767030715942383
# Temps de suppression des stop words : 2.047712802886963
# Temps de lemmatization : 2.854473829269409
# Temps de Byte-pair Encoding sur les paires de mots : 1.1803579330444336
# Temps de vectorisation : 1.0474755764007568
# Temps de normalisation : 0.009780406951904297
# Temps de mise en minuscule : 0.0030717849731445312
# Temps de suppression de la ponctuation : 0.05629992485046387
# Temps de suppression des nombres : 0.10486173629760742
# Temps de suppression des stop words : 1.7489380836486816
# Temps de lemmatization : 2.1059441566467285
# Temps de Byte-pair Encoding sur les paires de mots : 1.0788195133209229
# Temps de vectorisation : 0.9967079162597656
# Temps de normalisation : 0.009657621383666992
# Temps de mise en minuscule : 0.0031311511993408203
# Temps de suppression de la ponctuation : 0.05189061164855957
# Temps de suppression des nombres : 0.09923505783081055
# Temps de suppression des stop words : 1.8727195262908936
# Temps de lemmatization : 2.1233022212982178
# Temps de Byte-pair Encoding sur les paires de mots : 1.0939257144927979
# Temps de vectorisation : 1.0110435485839844
# Temps de normalisation : 0.009089469909667969
# Temps de mise en minuscule : 0.002599000930786133
# Temps de suppression de la ponctuation : 0.0518488883972168
# Temps de suppression des nombres : 0.09891963005065918
# Temps de suppression des stop words : 1.7879834175109863
# Temps de lemmatization : 2.1272048950195312
# Temps de Byte-pair Encoding sur les paires de mots : 1.0863206386566162
# Temps de vectorisation : 0.9840459823608398
# Temps de normalisation : 0.009315729141235352
# Temps de mise en minuscule : 0.0027437210083007812
# Temps de suppression de la ponctuation : 0.05185699462890625
# Temps de suppression des nombres : 0.09682750701904297
# Temps de suppression des stop words : 1.7822391986846924
# Temps de lemmatization : 2.1304078102111816
# Temps de Byte-pair Encoding sur les paires de mots : 1.0956838130950928
# Temps de vectorisation : 1.0337913036346436
# Temps de normalisation : 0.009042501449584961
# Temps de mise en minuscule : 0.0026731491088867188
# Temps de suppression de la ponctuation : 0.05177760124206543
# Temps de suppression des nombres : 0.09668684005737305
# Temps de suppression des stop words : 1.8018431663513184
# Temps de lemmatization : 2.2671468257904053
# Temps de Byte-pair Encoding sur les paires de mots : 1.8045015335083008
# Temps de vectorisation : 1.001258134841919
# Temps de normalisation : 0.009027481079101562
# Temps de mise en minuscule : 0.0026636123657226562
# Temps de suppression de la ponctuation : 0.0509946346282959
# Temps de suppression des nombres : 0.0949409008026123
# Temps de suppression des stop words : 1.795802354812622
# Temps de lemmatization : 2.134387969970703
# Temps de Byte-pair Encoding sur les paires de mots : 1.0901296138763428
# Temps de vectorisation : 1.0025074481964111
# Temps de normalisation : 0.009045839309692383
# Temps de mise en minuscule : 0.002652406692504883
# Temps de suppression de la ponctuation : 0.052154541015625
# Temps de suppression des nombres : 0.09548068046569824
# Temps de suppression des stop words : 1.7954881191253662
# Temps de lemmatization : 2.1449825763702393
# Temps de Byte-pair Encoding sur les paires de mots : 1.0982446670532227
# Temps de vectorisation : 0.9867138862609863
# Temps de normalisation : 0.009194612503051758
# Temps de mise en minuscule : 0.002690553665161133
# Temps de suppression de la ponctuation : 0.05133843421936035
# Temps de suppression des nombres : 0.09749221801757812
# Temps de suppression des stop words : 1.818610429763794
# Temps de lemmatization : 2.7114908695220947
# Temps de Byte-pair Encoding sur les paires de mots : 1.1441402435302734
# Temps de vectorisation : 1.1482634544372559
# Temps de normalisation : 0.010032415390014648
# Temps de mise en minuscule : 0.0030286312103271484
# Temps de suppression de la ponctuation : 0.05757260322570801
# Temps de suppression des nombres : 0.10886335372924805
# Temps de suppression des stop words : 2.1079206466674805
# Temps de lemmatization : 2.332827568054199
# Temps de Byte-pair Encoding sur les paires de mots : 1.192084550857544
# Temps de vectorisation : 1.0987253189086914
# Temps de normalisation : 0.009767293930053711
# Temps de mise en minuscule : 0.002867460250854492
# Temps de suppression de la ponctuation : 0.05445075035095215
# Temps de suppression des nombres : 0.10138678550720215
# Temps de suppression des stop words : 1.9291739463806152
# Temps de lemmatization : 2.415114641189575
# Temps de Byte-pair Encoding sur les paires de mots : 1.3222131729125977
# Temps de vectorisation : 1.1388278007507324
# Temps de normalisation : 0.009949922561645508
# Temps de mise en minuscule : 0.0028543472290039062
# Temps de suppression de la ponctuation : 0.05448007583618164
# Temps de suppression des nombres : 0.10239577293395996
# Temps de suppression des stop words : 2.1075267791748047
# Temps de lemmatization : 3.066222667694092
# Temps de Byte-pair Encoding sur les paires de mots : 1.334235429763794
# Temps de vectorisation : 1.1578164100646973
# Temps de normalisation : 0.01016545295715332
# Temps de mise en minuscule : 0.0030155181884765625
# Temps de suppression de la ponctuation : 0.05620169639587402
# Temps de suppression des nombres : 0.10416316986083984
# Temps de suppression des stop words : 2.0550131797790527
# Temps de lemmatization : 2.395663022994995
# Temps de Byte-pair Encoding sur les paires de mots : 1.2614736557006836
# Temps de vectorisation : 1.1982462406158447
# Temps de normalisation : 0.011924028396606445
# Temps de mise en minuscule : 0.003903627395629883
# Temps de suppression de la ponctuation : 0.06712746620178223
# Temps de suppression des nombres : 0.12208318710327148
# Temps de suppression des stop words : 2.3070285320281982
# Temps de lemmatization : 2.546186923980713
# Temps de Byte-pair Encoding sur les paires de mots : 1.2418262958526611
# Temps de normalisation : 0.01004934310913086
# Temps de mise en minuscule : 0.002946138381958008
# Temps de suppression de la ponctuation : 0.05675148963928223
# Temps de suppression des nombres : 0.10685133934020996
# Temps de suppression des stop words : 2.0508058071136475
# Temps de lemmatization : 2.5802512168884277
# Temps de Byte-pair Encoding sur les paires de mots : 1.2613942623138428
# Temps de normalisation : 0.009908437728881836
# Temps de mise en minuscule : 0.003380298614501953
# Temps de suppression de la ponctuation : 0.06193256378173828
# Temps de suppression des nombres : 0.11091375350952148
# Temps de suppression des stop words : 2.0660746097564697
# Temps de lemmatization : 2.527611494064331
# Temps de Byte-pair Encoding sur les paires de mots : 1.292189121246338
# Temps de vectorisation : 0.5222053527832031
# Temps de normalisation : 0.010766983032226562
# Temps de mise en minuscule : 0.003191709518432617
# Temps de suppression de la ponctuation : 0.05973458290100098
# Temps de suppression des nombres : 0.10815191268920898
# Temps de suppression des stop words : 2.342646360397339
# Temps de lemmatization : 2.860302448272705
# Temps de Byte-pair Encoding sur les paires de mots : 1.8775572776794434
# Temps de vectorisation : 0.5316908359527588
# Temps de normalisation : 0.011044979095458984
# Temps de mise en minuscule : 0.0034017562866210938
# Temps de suppression de la ponctuation : 0.06564068794250488
# Temps de suppression des nombres : 0.1164255142211914
# Temps de suppression des stop words : 2.208333969116211
# Temps de lemmatization : 2.741875648498535
# Temps de Byte-pair Encoding sur les paires de mots : 1.3091168403625488
# Temps de vectorisation : 0.5264253616333008
# Temps de normalisation : 0.010745525360107422
# Temps de mise en minuscule : 0.0030858516693115234
# Temps de suppression de la ponctuation : 0.0640864372253418
# Temps de suppression des nombres : 0.11802196502685547
# Temps de suppression des stop words : 2.196455955505371
# Temps de lemmatization : 2.5922248363494873
# Temps de Byte-pair Encoding sur les paires de mots : 1.3229405879974365
# Temps de vectorisation : 0.5319726467132568
# Temps de normalisation : 0.010734319686889648
# Temps de mise en minuscule : 0.0034072399139404297
# Temps de suppression de la ponctuation : 0.05365180969238281
# Temps de suppression des nombres : 0.10243701934814453
# Temps de suppression des stop words : 1.992086410522461
# Temps de lemmatization : 2.3730223178863525
# Temps de Byte-pair Encoding sur les paires de mots : 1.1954338550567627
# Temps de vectorisation : 0.5076866149902344
# Temps de normalisation : 0.010179281234741211
# Temps de mise en minuscule : 0.0029785633087158203
# Temps de suppression de la ponctuation : 0.060415029525756836
# Temps de suppression des nombres : 0.11057615280151367
# Temps de suppression des stop words : 2.062171459197998
# Temps de lemmatization : 2.4762368202209473
# Temps de Byte-pair Encoding sur les paires de mots : 1.2948267459869385
# Temps de vectorisation : 0.5120718479156494
# Temps de normalisation : 0.010103940963745117
# Temps de mise en minuscule : 0.003313779830932617
# Temps de suppression de la ponctuation : 0.05865621566772461
# Temps de suppression des nombres : 0.10918331146240234
# Temps de suppression des stop words : 2.0322816371917725
# Temps de lemmatization : 2.44195294380188
# Temps de Byte-pair Encoding sur les paires de mots : 1.271134614944458
# Temps de vectorisation : 0.5396878719329834
# Temps de normalisation : 0.011590957641601562
# Temps de mise en minuscule : 0.003477811813354492
# Temps de suppression de la ponctuation : 0.06774020195007324
# Temps de suppression des nombres : 0.12176299095153809
# Temps de suppression des stop words : 2.174159288406372
# Temps de lemmatization : 2.7519493103027344
# Temps de Byte-pair Encoding sur les paires de mots : 1.1544265747070312
# Temps de vectorisation : 0.5366818904876709
# Temps de normalisation : 0.010285615921020508
# Temps de mise en minuscule : 0.0031387805938720703
# Temps de suppression de la ponctuation : 0.05913567543029785
# Temps de suppression des nombres : 0.10567998886108398
# Temps de suppression des stop words : 2.048523426055908
# Temps de lemmatization : 2.528435468673706
# Temps de Byte-pair Encoding sur les paires de mots : 1.1902885437011719
# Temps de vectorisation : 0.5238237380981445
# Temps de normalisation : 0.010345220565795898
# Temps de mise en minuscule : 0.003167390823364258
# Temps de suppression de la ponctuation : 0.058010101318359375
# Temps de suppression des nombres : 0.10736966133117676
# Temps de suppression des stop words : 2.010313034057617
# Temps de lemmatization : 2.441328287124634
# Temps de Byte-pair Encoding sur les paires de mots : 1.2278192043304443
# Temps de vectorisation : 0.5227131843566895
# Temps de normalisation : 0.009539365768432617
# Temps de mise en minuscule : 0.0029582977294921875
# Temps de suppression de la ponctuation : 0.05395102500915527
# Temps de suppression des nombres : 0.10230565071105957
# Temps de suppression des stop words : 1.9938898086547852
# Temps de lemmatization : 2.3411293029785156
# Temps de Byte-pair Encoding sur les paires de mots : 1.174252986907959
# Temps de vectorisation : 0.5004012584686279
# Temps de normalisation : 0.009827852249145508
# Temps de mise en minuscule : 0.002813100814819336
# Temps de suppression de la ponctuation : 0.05645155906677246
# Temps de suppression des nombres : 0.1019599437713623
# Temps de suppression des stop words : 1.9449615478515625
# Temps de lemmatization : 2.33630633354187
# Temps de Byte-pair Encoding sur les paires de mots : 1.2868449687957764
# Temps de vectorisation : 0.496920108795166
# Temps de normalisation : 0.009857416152954102
# Temps de mise en minuscule : 0.0029630661010742188
# Temps de suppression de la ponctuation : 0.05711507797241211
# Temps de suppression des nombres : 0.10678267478942871
# Temps de suppression des stop words : 1.9436564445495605
# Temps de lemmatization : 2.3446269035339355
# Temps de Byte-pair Encoding sur les paires de mots : 1.1435458660125732
# Temps de vectorisation : 0.5044939517974854
# Temps de normalisation : 0.012026309967041016
# Temps de mise en minuscule : 0.0038645267486572266
# Temps de suppression de la ponctuation : 0.06714820861816406
# Temps de suppression des nombres : 0.12127971649169922
# Temps de suppression des stop words : 2.1363964080810547
# Temps de lemmatization : 2.3743979930877686
# Temps de Byte-pair Encoding sur les paires de mots : 1.1847114562988281
# Temps de vectorisation : 0.5150907039642334
# Temps de normalisation : 0.010226964950561523
# Temps de mise en minuscule : 0.003073453903198242
# Temps de suppression de la ponctuation : 0.05785393714904785
# Temps de suppression des nombres : 0.10531997680664062
# Temps de suppression des stop words : 2.0188777446746826
# Temps de lemmatization : 2.4361956119537354
# Temps de Byte-pair Encoding sur les paires de mots : 1.2252256870269775
# Temps de vectorisation : 0.5279614925384521
# Temps de normalisation : 0.010494232177734375
# Temps de mise en minuscule : 0.0030171871185302734
# Temps de suppression de la ponctuation : 0.05989789962768555
# Temps de suppression des nombres : 0.1106419563293457
# Temps de suppression des stop words : 2.179900884628296
# Temps de lemmatization : 2.4150097370147705
# Temps de Byte-pair Encoding sur les paires de mots : 1.2022857666015625
# Temps de vectorisation : 0.5375001430511475
# Temps de normalisation : 0.010539770126342773
# Temps de mise en minuscule : 0.0031273365020751953
# Temps de suppression de la ponctuation : 0.05887794494628906
# Temps de suppression des nombres : 0.10746002197265625
# Temps de suppression des stop words : 2.0414748191833496
# Temps de lemmatization : 2.539377450942993
# Temps de Byte-pair Encoding sur les paires de mots : 1.346496820449829
# Temps de vectorisation : 0.5717377662658691
# Temps de normalisation : 0.011005163192749023
# Temps de mise en minuscule : 0.0034570693969726562
# Temps de suppression de la ponctuation : 0.06483960151672363
# Temps de suppression des nombres : 0.11820197105407715
# Temps de suppression des stop words : 2.2388031482696533
# Temps de lemmatization : 2.673959732055664
# Temps de Byte-pair Encoding sur les paires de mots : 1.3391106128692627
# Temps de vectorisation : 0.5737464427947998
# Temps de normalisation : 0.011348962783813477
# Temps de mise en minuscule : 0.0033795833587646484
# Temps de suppression de la ponctuation : 0.06574463844299316
# Temps de suppression des nombres : 0.11871623992919922
# Temps de suppression des stop words : 2.2489852905273438
# Temps de lemmatization : 2.612055778503418
# Temps de Byte-pair Encoding sur les paires de mots : 1.31406831741333
# Temps de normalisation : 0.009873628616333008
# Temps de mise en minuscule : 0.003019571304321289
# Temps de suppression de la ponctuation : 0.05616569519042969
# Temps de suppression des nombres : 0.10471415519714355
# Temps de suppression des stop words : 2.0044755935668945
# Temps de lemmatization : 2.3504037857055664
# Temps de Byte-pair Encoding sur les paires de mots : 1.1961359977722168
# Temps de normalisation : 0.009296178817749023
# Temps de mise en minuscule : 0.0030825138092041016
# Temps de suppression de la ponctuation : 0.0578768253326416
# Temps de suppression des nombres : 0.1030113697052002
# Temps de suppression des stop words : 2.0960285663604736
# Temps de lemmatization : 2.464038848876953
# Temps de Byte-pair Encoding sur les paires de mots : 1.3320879936218262
# Temps de vectorisation : 0.9642496109008789
# Temps de normalisation : 0.009129524230957031
# Temps de mise en minuscule : 0.0028944015502929688
# Temps de suppression de la ponctuation : 0.05437421798706055
# Temps de suppression des nombres : 0.09375762939453125
# Temps de suppression des stop words : 1.8696537017822266
# Temps de lemmatization : 2.3496108055114746
# Temps de Byte-pair Encoding sur les paires de mots : 1.1784312725067139
# Temps de vectorisation : 0.9502530097961426
# Temps de normalisation : 0.009858846664428711
# Temps de mise en minuscule : 0.003039836883544922
# Temps de suppression de la ponctuation : 0.05700182914733887
# Temps de suppression des nombres : 0.10126447677612305
# Temps de suppression des stop words : 1.9422874450683594
# Temps de lemmatization : 2.287532091140747
# Temps de Byte-pair Encoding sur les paires de mots : 1.1639137268066406
# Temps de vectorisation : 0.9175167083740234
# Temps de normalisation : 0.009593963623046875
# Temps de mise en minuscule : 0.002814054489135742
# Temps de suppression de la ponctuation : 0.05715203285217285
# Temps de suppression des nombres : 0.10020208358764648
# Temps de suppression des stop words : 1.8929328918457031
# Temps de lemmatization : 2.308609962463379
# Temps de Byte-pair Encoding sur les paires de mots : 1.2285916805267334
# Temps de vectorisation : 0.9261000156402588
# Temps de normalisation : 0.009759664535522461
# Temps de mise en minuscule : 0.0029494762420654297
# Temps de suppression de la ponctuation : 0.05730175971984863
# Temps de suppression des nombres : 0.10171651840209961
# Temps de suppression des stop words : 2.4648079872131348
# Temps de lemmatization : 2.248479127883911
# Temps de Byte-pair Encoding sur les paires de mots : 1.1597380638122559
# Temps de vectorisation : 0.9166314601898193
# Temps de normalisation : 0.009650468826293945
# Temps de mise en minuscule : 0.003049612045288086
# Temps de suppression de la ponctuation : 0.05739235877990723
# Temps de suppression des nombres : 0.10186457633972168
# Temps de suppression des stop words : 1.9150652885437012
# Temps de lemmatization : 2.261995553970337
# Temps de Byte-pair Encoding sur les paires de mots : 1.1625938415527344
# Temps de vectorisation : 0.9209716320037842
# Temps de normalisation : 0.009757757186889648
# Temps de mise en minuscule : 0.0032308101654052734
# Temps de suppression de la ponctuation : 0.0575556755065918
# Temps de suppression des nombres : 0.10506081581115723
# Temps de suppression des stop words : 1.9285168647766113
# Temps de lemmatization : 2.372466564178467
# Temps de Byte-pair Encoding sur les paires de mots : 1.1362342834472656
# Temps de vectorisation : 0.9136121273040771
# Temps de normalisation : 0.010831356048583984
# Temps de mise en minuscule : 0.0028734207153320312
# Temps de suppression de la ponctuation : 0.060427188873291016
# Temps de suppression des nombres : 0.10450625419616699
# Temps de suppression des stop words : 1.970827579498291
# Temps de lemmatization : 2.2256267070770264
# Temps de Byte-pair Encoding sur les paires de mots : 1.1464781761169434
# Temps de vectorisation : 0.9339878559112549
# Temps de normalisation : 0.009647130966186523
# Temps de mise en minuscule : 0.002765178680419922
# Temps de suppression de la ponctuation : 0.05708599090576172
# Temps de suppression des nombres : 0.1012122631072998
# Temps de suppression des stop words : 1.8944132328033447
# Temps de lemmatization : 2.297917366027832
# Temps de Byte-pair Encoding sur les paires de mots : 1.1606817245483398
# Temps de vectorisation : 0.9115962982177734
# Temps de normalisation : 0.009836673736572266
# Temps de mise en minuscule : 0.0029458999633789062
# Temps de suppression de la ponctuation : 0.05635571479797363
# Temps de suppression des nombres : 0.10259890556335449
# Temps de suppression des stop words : 1.9165263175964355
# Temps de lemmatization : 3.003932476043701
# Temps de Byte-pair Encoding sur les paires de mots : 1.2072060108184814
# Temps de vectorisation : 0.9015998840332031
# Temps de normalisation : 0.009482145309448242
# Temps de mise en minuscule : 0.0029287338256835938
# Temps de suppression de la ponctuation : 0.05483388900756836
# Temps de suppression des nombres : 0.09709548950195312
# Temps de suppression des stop words : 2.009204387664795
# Temps de lemmatization : 2.342226266860962
# Temps de Byte-pair Encoding sur les paires de mots : 1.118964672088623
# Temps de vectorisation : 0.9148404598236084
# Temps de normalisation : 0.009927749633789062
# Temps de mise en minuscule : 0.003123044967651367
# Temps de suppression de la ponctuation : 0.05451655387878418
# Temps de suppression des nombres : 0.09832930564880371
# Temps de suppression des stop words : 1.8437252044677734
# Temps de lemmatization : 2.2293477058410645
# Temps de Byte-pair Encoding sur les paires de mots : 1.1168394088745117
# Temps de vectorisation : 0.9083132743835449
# Temps de normalisation : 0.00989079475402832
# Temps de mise en minuscule : 0.002949953079223633
# Temps de suppression de la ponctuation : 0.05538582801818848
# Temps de suppression des nombres : 0.09762406349182129
# Temps de suppression des stop words : 1.8422021865844727
# Temps de lemmatization : 2.213852643966675
# Temps de Byte-pair Encoding sur les paires de mots : 1.1252241134643555
# Temps de vectorisation : 0.9055581092834473
# Temps de normalisation : 0.009505987167358398
# Temps de mise en minuscule : 0.002820253372192383
# Temps de suppression de la ponctuation : 0.05615401268005371
# Temps de suppression des nombres : 0.09904599189758301
# Temps de suppression des stop words : 1.9995543956756592
# Temps de lemmatization : 2.3088748455047607
# Temps de Byte-pair Encoding sur les paires de mots : 1.1540048122406006
# Temps de vectorisation : 0.8873846530914307
# Temps de normalisation : 0.013160228729248047
# Temps de mise en minuscule : 0.002920866012573242
# Temps de suppression de la ponctuation : 0.056964874267578125
# Temps de suppression des nombres : 0.10116887092590332
# Temps de suppression des stop words : 1.9071145057678223
# Temps de lemmatization : 2.24751877784729
# Temps de Byte-pair Encoding sur les paires de mots : 1.1418952941894531
# Temps de vectorisation : 1.0453739166259766
# Temps de normalisation : 0.009706258773803711
# Temps de mise en minuscule : 0.002890348434448242
# Temps de suppression de la ponctuation : 0.056668996810913086
# Temps de suppression des nombres : 0.10147809982299805
# Temps de suppression des stop words : 1.9137349128723145
# Temps de lemmatization : 2.2659873962402344
# Temps de Byte-pair Encoding sur les paires de mots : 1.1170978546142578
# Temps de vectorisation : 0.8976142406463623
# Temps de normalisation : 0.009586572647094727
# Temps de mise en minuscule : 0.0032186508178710938
# Temps de suppression de la ponctuation : 0.05388045310974121
# Temps de suppression des nombres : 0.09540176391601562
# Temps de suppression des stop words : 2.0136566162109375
# Temps de lemmatization : 2.309462785720825
# Temps de Byte-pair Encoding sur les paires de mots : 1.17681884765625
# Temps de vectorisation : 0.9039285182952881
# Temps de normalisation : 0.00970911979675293
# Temps de mise en minuscule : 0.0029604434967041016
# Temps de suppression de la ponctuation : 0.05535697937011719
# Temps de suppression des nombres : 0.10166811943054199
# Temps de suppression des stop words : 1.8718135356903076
# Temps de lemmatization : 2.2462289333343506
# Temps de Byte-pair Encoding sur les paires de mots : 1.1373052597045898
# Temps de vectorisation : 0.8907432556152344
# Temps de normalisation : 0.009772777557373047
# Temps de mise en minuscule : 0.0028803348541259766
# Temps de suppression de la ponctuation : 0.05690407752990723
# Temps de suppression des nombres : 0.10046720504760742
# Temps de suppression des stop words : 2.066582202911377
# Temps de lemmatization : 2.483816385269165
# Temps de Byte-pair Encoding sur les paires de mots : 1.2301139831542969
# Temps de normalisation : 0.009562015533447266
# Temps de mise en minuscule : 0.002969503402709961
# Temps de suppression de la ponctuation : 0.06106090545654297
# Temps de suppression des nombres : 0.11062502861022949
# Temps de suppression des stop words : 2.033517360687256
# Temps de lemmatization : 2.51737642288208
# Temps de Byte-pair Encoding sur les paires de mots : 1.2096226215362549
# Temps de normalisation : 0.009464025497436523
# Temps de mise en minuscule : 0.0028963088989257812
# Temps de suppression de la ponctuation : 0.052443504333496094
# Temps de suppression des nombres : 0.09128165245056152
# Temps de suppression des stop words : 1.8931598663330078
# Temps de lemmatization : 2.686331272125244
# Temps de Byte-pair Encoding sur les paires de mots : 1.0839087963104248
# Temps de vectorisation : 0.473376989364624
# Temps de normalisation : 0.009320974349975586
# Temps de mise en minuscule : 0.0027780532836914062
# Temps de suppression de la ponctuation : 0.05353236198425293
# Temps de suppression des nombres : 0.09486722946166992
# Temps de suppression des stop words : 1.8460240364074707
# Temps de lemmatization : 2.251328706741333
# Temps de Byte-pair Encoding sur les paires de mots : 1.0787651538848877
# Temps de vectorisation : 0.439678430557251
# Temps de normalisation : 0.009283781051635742
# Temps de mise en minuscule : 0.0029218196868896484
# Temps de suppression de la ponctuation : 0.056046247482299805
# Temps de suppression des nombres : 0.09624242782592773
# Temps de suppression des stop words : 1.8244173526763916
# Temps de lemmatization : 2.428926467895508
# Temps de Byte-pair Encoding sur les paires de mots : 1.1060771942138672
# Temps de vectorisation : 0.4372239112854004
# Temps de normalisation : 0.009304046630859375
# Temps de mise en minuscule : 0.002837657928466797
# Temps de suppression de la ponctuation : 0.05420064926147461
# Temps de suppression des nombres : 0.09777712821960449
# Temps de suppression des stop words : 1.8645873069763184
# Temps de lemmatization : 2.2011606693267822
# Temps de Byte-pair Encoding sur les paires de mots : 1.0985345840454102
# Temps de vectorisation : 0.46161746978759766
# Temps de normalisation : 0.009452104568481445
# Temps de mise en minuscule : 0.0031328201293945312
# Temps de suppression de la ponctuation : 0.05557131767272949
# Temps de suppression des nombres : 0.09889745712280273
# Temps de suppression des stop words : 1.8436071872711182
# Temps de lemmatization : 2.182004690170288
# Temps de Byte-pair Encoding sur les paires de mots : 1.1047289371490479
# Temps de vectorisation : 0.44090867042541504
# Temps de normalisation : 0.009437799453735352
# Temps de mise en minuscule : 0.0027511119842529297
# Temps de suppression de la ponctuation : 0.05452156066894531
# Temps de suppression des nombres : 0.09955072402954102
# Temps de suppression des stop words : 1.8551456928253174
# Temps de lemmatization : 2.3150699138641357
# Temps de Byte-pair Encoding sur les paires de mots : 1.109109878540039
# Temps de vectorisation : 0.4442732334136963
# Temps de normalisation : 0.009224176406860352
# Temps de mise en minuscule : 0.0028562545776367188
# Temps de suppression de la ponctuation : 0.05515003204345703
# Temps de suppression des nombres : 0.09683394432067871
# Temps de suppression des stop words : 1.9103631973266602
# Temps de lemmatization : 2.7048943042755127
# Temps de Byte-pair Encoding sur les paires de mots : 1.2558963298797607
# Temps de vectorisation : 0.49617552757263184
# Temps de normalisation : 0.010587692260742188
# Temps de mise en minuscule : 0.0034875869750976562
# Temps de suppression de la ponctuation : 0.060886383056640625
# Temps de suppression des nombres : 0.10749316215515137
# Temps de suppression des stop words : 1.9290757179260254
# Temps de lemmatization : 2.2504334449768066
# Temps de Byte-pair Encoding sur les paires de mots : 1.0979278087615967
# Temps de vectorisation : 0.4637455940246582
# Temps de normalisation : 0.009395599365234375
# Temps de mise en minuscule : 0.002737283706665039
# Temps de suppression de la ponctuation : 0.05427289009094238
# Temps de suppression des nombres : 0.09538006782531738
# Temps de suppression des stop words : 1.852367877960205
# Temps de lemmatization : 2.4125514030456543
# Temps de Byte-pair Encoding sur les paires de mots : 1.103257179260254
# Temps de vectorisation : 0.4551353454589844
# Temps de normalisation : 0.009606361389160156
# Temps de mise en minuscule : 0.0027551651000976562
# Temps de suppression de la ponctuation : 0.05496501922607422
# Temps de suppression des nombres : 0.09802007675170898
# Temps de suppression des stop words : 1.8607046604156494
# Temps de lemmatization : 2.220877170562744
# Temps de Byte-pair Encoding sur les paires de mots : 1.1193296909332275
# Temps de vectorisation : 0.462735652923584
# Temps de normalisation : 0.009818077087402344
# Temps de mise en minuscule : 0.0030062198638916016
# Temps de suppression de la ponctuation : 0.05537581443786621
# Temps de suppression des nombres : 0.09694409370422363
# Temps de suppression des stop words : 1.8462514877319336
# Temps de lemmatization : 2.204603433609009
# Temps de Byte-pair Encoding sur les paires de mots : 1.089482069015503
# Temps de vectorisation : 0.4503345489501953
# Temps de normalisation : 0.010912656784057617
# Temps de mise en minuscule : 0.0030858516693115234
# Temps de suppression de la ponctuation : 0.060518503189086914
# Temps de suppression des nombres : 0.1053774356842041
# Temps de suppression des stop words : 2.066100597381592
# Temps de lemmatization : 2.6208527088165283
# Temps de Byte-pair Encoding sur les paires de mots : 1.1856253147125244
# Temps de vectorisation : 0.4794316291809082
# Temps de normalisation : 0.011238336563110352
# Temps de mise en minuscule : 0.0036432743072509766
# Temps de suppression de la ponctuation : 0.059420108795166016
# Temps de suppression des nombres : 0.10616374015808105
# Temps de suppression des stop words : 2.0708374977111816
# Temps de lemmatization : 2.8842296600341797
# Temps de Byte-pair Encoding sur les paires de mots : 1.1900138854980469
# Temps de vectorisation : 0.460735559463501
# Temps de normalisation : 0.010064363479614258
# Temps de mise en minuscule : 0.003055572509765625
# Temps de suppression de la ponctuation : 0.05941033363342285
# Temps de suppression des nombres : 0.10304832458496094
# Temps de suppression des stop words : 1.9752070903778076
# Temps de lemmatization : 2.356984853744507
# Temps de Byte-pair Encoding sur les paires de mots : 1.1643016338348389
# Temps de vectorisation : 0.45515990257263184
# Temps de normalisation : 0.010014772415161133
# Temps de mise en minuscule : 0.002677440643310547
# Temps de suppression de la ponctuation : 0.058640480041503906
# Temps de suppression des nombres : 0.10282111167907715
# Temps de suppression des stop words : 1.8323228359222412
# Temps de lemmatization : 2.2695937156677246
# Temps de Byte-pair Encoding sur les paires de mots : 1.0712780952453613
# Temps de vectorisation : 0.43638038635253906
# Temps de normalisation : 0.009795904159545898
# Temps de mise en minuscule : 0.0030841827392578125
# Temps de suppression de la ponctuation : 0.05506324768066406
# Temps de suppression des nombres : 0.09664273262023926
# Temps de suppression des stop words : 1.8398725986480713
# Temps de lemmatization : 2.1853034496307373
# Temps de Byte-pair Encoding sur les paires de mots : 1.1661529541015625
# Temps de vectorisation : 0.45562028884887695
# Temps de normalisation : 0.009866476058959961
# Temps de mise en minuscule : 0.0030248165130615234
# Temps de suppression de la ponctuation : 0.05720782279968262
# Temps de suppression des nombres : 0.10001277923583984
# Temps de suppression des stop words : 1.9592814445495605
# Temps de lemmatization : 2.299762487411499
# Temps de Byte-pair Encoding sur les paires de mots : 1.1391386985778809
# Temps de vectorisation : 0.44960784912109375
# Temps de normalisation : 0.010715484619140625
# Temps de mise en minuscule : 0.003152608871459961
# Temps de suppression de la ponctuation : 0.05898880958557129
# Temps de suppression des nombres : 0.10190677642822266
# Temps de suppression des stop words : 1.9977517127990723
# Temps de lemmatization : 2.2898130416870117
# Temps de Byte-pair Encoding sur les paires de mots : 1.2495739459991455
# Temps de vectorisation : 0.44559454917907715
# Temps de normalisation : 0.009814739227294922
# Temps de mise en minuscule : 0.003146648406982422
# Temps de suppression de la ponctuation : 0.0577542781829834
# Temps de suppression des nombres : 0.10106492042541504
# Temps de suppression des stop words : 1.93937087059021
# Temps de lemmatization : 2.644702434539795
# Temps de Byte-pair Encoding sur les paires de mots : 1.1337945461273193
# Temps de vectorisation : 0.17764067649841309
# Temps de normalisation : 0.018407106399536133
# Temps de mise en minuscule : 0.0057506561279296875
# Temps de suppression de la ponctuation : 0.10537266731262207
# Temps de suppression des nombres : 0.20065546035766602
# Temps de suppression des stop words : 3.6645214557647705
# Temps de lemmatization : 4.216020822525024
# Temps de Byte-pair Encoding sur les paires de mots : 2.1302051544189453
# Temps de vectorisation : 0.3180391788482666

# %% [markdown]
# Nous avons donc à la fois notre pre-processing optimal et notre modèle optimal, nous pouvons désormais fitter le modèle avec nos données et prédire les labels des données de test.

# %%
print("Score de test", best_score)
print("Score de train", best_train_score)
# Out:
# Score de test 0.7250821181508089
# Score de train 0.8013217671305932

# %% [markdown]
# Léger overfitting, nous pouvons néanmoins nous attendre à un score de ~70% de bonnes prédictions.

# %%
import sys

model_tofit.fit(bow_train_opt, y_train)
y_pred = np.where(np.array(model_tofit.predict(bow_test_opt))==1, 'C', 'M')

with open("result_pres.txt", "w") as f:
    for y_pred_i in y_pred:
        f.write(y_pred_i+"\n")
